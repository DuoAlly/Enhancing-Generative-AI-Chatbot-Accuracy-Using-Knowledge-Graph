# %% [markdown]
# <p> ################################################################## </p>
# <p>#&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;#
# <p> # This source code is adopted from Tomaz and modified for NWMSU chatbot application  &nbsp; #</p>
# <p>#&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;#
# <p></p>
# <p></p>
# <p> ################################################################## </p>

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %cd gdrive/My Drive
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive

# %% [markdown]
# Requirements:
#
# 1. **LangChain**: A framework for developing applications powered by language models.
# 2. **LangChain-Community**: A collaborative space for sharing resources, tools, and discussions related to LangChain.
# 3. **LangChain-OpenAI**: A LangChain extension providing integration with OpenAI's language models.
# 4. **LangChain-Experimental**: A repository for experimental features and prototypes within the LangChain ecosystem.
# 5. **Neo4j**: A graph database management system designed for handling and querying connected data.
# 6. **tiktoken**: A library for tokenizing text, commonly used with language models to preprocess input and output.
# 7. **yfiles_jupyter_graphs**: A library for creating and visualizing graphs and network diagrams in Jupyter notebooks.
# 8. **Streamlit**: An open-source framework for building interactive, web-based applications using Python.
# 9. **Localtunnel**: A tool that allows you to expose your local web server to the internet via a secure tunnel.

# %%
# %pip install --upgrade --quiet  langchain langchain-community langchain-openai langchain-experimental neo4j tiktoken yfiles_jupyter_graphs streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.0/203.0 kB 18.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 45.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 43.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 58.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 30.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 21.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 65.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 86.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.0 MB/s eta 0:00:00
#   Building wheel for neo4j (pyproject.toml) ... done

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/gdrive/MyDrive/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/gdrive/MyDrive/package.json'
# npm WARN MyDrive No description
# npm WARN MyDrive No repository field.
# npm WARN MyDrive No README data
# npm WARN MyDrive No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 28.899s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 2 moderate severity vulnerabilities
#   run `npm audit fix` to fix them, or `npm audit` for details

# %% [markdown]
# The provided code imports several components from different libraries, each serving a specific purpose. The `RunnableBranch`, `RunnableLambda`, `RunnableParallel`, and `RunnablePassthrough` from LangChain Core are utilities for creating complex workflows involving branching logic, function definitions, parallel execution, and straightforward data passing. For crafting prompts, `ChatPromptTemplate` and `PromptTemplate` are used to design structured inputs for language models.
#
# The `BaseModel` and `Field` from Pydantic assist in data validation and configuration, while typing utilities like `Tuple`, `List`, and `Optional` are used for type hinting in Python code. The message classes `AIMessage` and `HumanMessage` define interactions between an AI and a user. The `StrOutputParser` is employed for converting outputs into string format.
#
# The `os` module provides a way to interact with the operating system, and `Neo4jGraph` facilitates working with Neo4j databases. `TokenTextSplitter` helps in breaking down text into manageable tokens, essential for language processing. `ChatOpenAI` enables communication with OpenAI's chat models, and `LLMGraphTransformer` is used for transforming graph data with language models. For database interaction, `GraphDatabase` connects with Neo4j, and `GraphWidget` allows for the creation and visualization of graphs in Jupyter notebooks.
#
# Further, `Neo4jVector` supports storing and retrieving embeddings in Neo4j, while `OpenAIEmbeddings` provides tools for generating embeddings from OpenAI models. The `remove_lucene_chars` function cleans text by removing specific characters, ensuring data is properly formatted for Neo4j. Lastly, `ConfigurableField` allows for configurable data fields within a runnable, aiding in the customization of workflows.

# %%
# %%writefile main.py

from langchain_core.runnables import (
    RunnableBranch,
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from typing import Tuple, List, Optional
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser
import os
from langchain_community.graphs import Neo4jGraph
from langchain.text_splitter import TokenTextSplitter
from langchain_openai import ChatOpenAI
from langchain_experimental.graph_transformers import LLMGraphTransformer
from neo4j import GraphDatabase
from yfiles_jupyter_graphs import GraphWidget
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores.neo4j_vector import remove_lucene_chars
from langchain_core.runnables import ConfigurableField, RunnableParallel, RunnablePassthrough


try:
  import google.colab
  from google.colab import output
  output.enable_custom_widget_manager()
except:
  pass

# %% [markdown]
# These lines of code set environment variables for accessing the OpenAI API and a Neo4j database:
#
# - `os.environ["OPENAI_API_KEY"] = "sk-...."` sets the API key for accessing OpenAI's services.
# - `os.environ["NEO4J_URI"] = "bolt+s://d......databases.neo4j.io:7687"` specifies the URI for connecting to the Neo4j database.
# - `os.environ["NEO4J_USERNAME"] = "usr"` sets the username for the Neo4j database connection.
# - `os.environ["NEO4J_PASSWORD"] = "pwd"` sets the password for the Neo4j database connection.
#
# These environment variables are crucial for securely storing sensitive information required for connecting to external services.

# %%
os.environ["OPENAI_API_KEY"] = "sk-...................."
os.environ["NEO4J_URI"] = "bolt+s://d...........databases.neo4j.io:7687"
os.environ["NEO4J_USERNAME"] = "usr"
os.environ["NEO4J_PASSWORD"] = "pwd"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 os.environ["OPENAI_API_KEY"] = "sk-...................."
#       2 os.environ["NEO4J_URI"] = "bolt+s://d...........databases.neo4j.io:7687"
#       3 os.environ["NEO4J_USERNAME"] = "usr"
#
# NameError: name 'os' is not defined

# %% [markdown]
# This instance, stored in the variable graph, can be used to interact with the Neo4j database. The Neo4jGraph class provides methods and functionalities to execute queries, retrieve data, and manipulate the graph database, facilitating seamless integration and operations within the LangChain framework.

# %%
graph = Neo4jGraph()

# %% [markdown]
# This code snippet loads web pages from a list of URLs using the `WebBaseLoader` class from the `langchain_community.document_loaders` module:
#
#
# - **WebBaseLoader**: This class is used for loading web pages from URLs provided in a list. It likely uses web scraping techniques to retrieve the content from each URL.
# - **loader.requests_kwargs**: This line sets a keyword argument for the HTTP request made by the loader. `{'verify': False}` disables SSL certificate verification, which can be useful when dealing with self-signed certificates or testing environments.
# - **data = loader.load()**: This line executes the loading process, fetching the HTML content from the specified URLs and storing it in the `data` variable.
#
# This approach is helpful for gathering content from multiple web pages for further processing, such as natural language processing or content analysis, within the LangChain framework.

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(["https://www.nwmissouri.edu/csis/msacs/",
                        "https://www.nwmissouri.edu/csis/msacs/about.htm",
                        "https://www.nwmissouri.edu/academics/graduate/masters/applied-computer-science.htm",
                        "https://www.nwmissouri.edu/csis/msacs/apply/index.htm",
                        "https://www.nwmissouri.edu/csis/msacs/courses.htm",
                        "https://www.nwmissouri.edu/csis/msacs/current/projects/index.htm",
                        "https://www.nwmissouri.edu/csis/msacs/current/research.htm",
                        "https://www.nwmissouri.edu/csis/msacs/finaid.htm",
                        "https://www.nwmissouri.edu/csis/msacs/on-campus-employment.htm",
                        "https://www.nwmissouri.edu/csis/msacs/internship-and-cpt.htm",
                        "https://www.nwmissouri.edu/csis/orgs/index.htm",
                        "https://www.nwmissouri.edu/csis/msacs/FAQs.htm",
                        "https://www.nwmissouri.edu/csis/msacs/contact.htm"
                        ])
loader.requests_kwargs = {'verify':False}
data = loader.load()
# print(data)
# Out:
# WARNING:root:USER_AGENT environment variable not set, consider setting it to identify your requests.
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nwmissouri.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
data
# Out:
# [Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\xa0\n\xa0\n\n\n » CSIS\nWelcome to Masters in Applied Computer Science\n\n\n\nAt Northwest, we are dedicated towards the development of future leaders in the information technology (IT) industry. Our highly qualified faculty members collaborate and work together to educate students who come to obtain a quality education. We provide appropriate technological and instructional resources for our students to help them succeed in the IT job market worldwide. Northwest is also committed towards the personal and social development of its students by providing opportunities for our students to interact with others in a successful, ethical way.Prospective MS-ACS StudentsAdmissions information for prospective international students.MSACS on FacebookFollow the Masters in Applied Computer Science program on Facebook!\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/', 'title': 'MS-ACS | School of Computer Science & Information Systems | Northwest', 'description': 'Northwest Missouri State University is committed to developing future leaders in the IT industry through the Masters in Applied Computer Science program.', 'language': 'en'}),
#  Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nWhy MS-Applied Computer Science Program?\n\n\n\nThe Program\nThe Master of Science in Applied Computer Science offers students with strong undergraduate background in a technical computing discipline an opportunity to increase their technical expertise and to complement that expertise with fundamental business concepts related specifically to information technology. The term Applied Computer Science was carefully chosen. The practical skills developed for a wide variety of high-demand areas, as well as the firm conceptual foundation provided by the program, combine to create graduates that are well-prepared to succeed in a very competitive job market.\nThe M.S. Applied Computer Science program has a STEM CIP code 11.0701 that currently allows an extra 24 months of OPT (Optional Practical Training) extension after completion of 12 month OPT period. Visit U.S. Citizenship and Immigration Services for updates.\nFor more details about the program, see Program Description.\nOverview of Program, School and University\n\nThe average class size at Northwest is 27.\nStudent to faculty ratio is 22 to 1.\nBetween 75 and 375 graduate students are normally enrolled in the M.S. in Applied Computer Science program.\nNorthwest Missouri State University is home to the Missouri Arboretum, providing a beautiful environment for all members of the university community.\nNorthwest is considered one of the safest campuses in the nation.\n\nComputing Facilities\nThe Electronic Campus gives students access to the Internet and to the Missouri Research and Education Network. Computer languages supported on the network include \xa0Java, C#, C++, Perl, Smalltalk, Node JS, Android Studio, and Swift.\xa0Databases include SQL, NoSQL, SQL Server, MongoDB, and Oracle 12c.\nAll students have access to specialized computer laboratories housed in the Colden Hall Computing Complex. In addition, every full-time student is provided with a laptop by the University. There are multiple wireless access points on campus.\nGraduate Research\nAll graduate students in the MS-Applied Computer Science program are required to complete a two-semester software development project during their last two semesters of their study. For a list of recent projects, see the projects page.\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/about.htm', 'title': 'MS-ACS |  ...
#  Document(page_content="\n\n\n\n\n\n\nApplied Computer Science | Graduate Program\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nAcademics\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nMajors and Minors\nSchools and Departments\nFaculty Credentials\nAcademic Calendar\nAcademic Catalogs\nServices & Support \n\nAssessment Office\nLibrary\nNorthwest Success 360\nStudent Success Center\nTextbook Services\nStudents with Disabilities\nWriting Center\n\n\nOther Learning Opportunities \n\nGraduate School\nHonors Program\nOnline Programs\nContinuing Professional Education / Professional Development\nNorthwest-Kansas City\nDual Credit\nHorace Mann Laboratory School\n\n\nRelated Links \n\nProvost's Office\n\n\n\n\n\n\n\n\n\xa0\n\xa0\n\n\n » Academics\nApplied Computer Science\n\n\n\nProgram(s) Available: M.S.Northwest’s Master of Science in Applied Computer Science is a 16-month program that offers hands-on, professional education in today's high-demand areas, including big data, web and cross-platform mobile development, security and user experience design. Computer Science is projected to grow by 15% by 2029, a growth rate larger than any other program.\n*Enrollment Open to Students on F-1 VisasWhy Study \r\n        \t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\tApplied Computer Science at Northwest\r\n        \t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\tNorthwest is an electronic campus that gives students access to the internet and the Missouri Research and Education Network.\xa0Computer languages and tools supported on the network include Java, C#, Swift, Hadoop, and Tableau. Databases include SQL, SQL Server, MongoDB and Oracle 12c.\nAll students have access to specialized computer laboratories housed in the Colden Hall Computing Complex.\nApplied development courses coupled with data, projects as well as software and IT management enable students to distinguish themselves and graduate ready to contribute in a competitive, global market.\nLearn more about the ASC ProgramContactSchool of Computer Science and Information Systems660.562.1600timmel@nwmissouri.eduRelated LinksAcademic CatalogDepartment WebsiteStudent OrganizationsQuick LinksSchedule a VisitAcademic CatalogDepartment WebsiteStudent OrganizationsCareer opportunities\nComputer and information research science\nComputer network architecture\nComputer programmer\nComputer system analyst\nWeb developer\nMore detailsAdmissions requirementsCandidates for the Master of Science in Applied Computer Science should meet the following requirements:\n\nAcceptance to the Graduate School by the Dean of the Graduate School\nCompleting a bachelor’s degree from an accredited college or university with a minimum grade-point average of 3.00 on a 4.00 scale.\nHave an undergraduate major or minor in a technical computing discipline with coursework in\r\n\ndata structures\ncomputer networks (or) network fundamentals\ndatabase systems\ndiscrete mathematics\nstatistics\n\n\n\nApplicants not satisfying these requirements may take undergraduate-level courses to remove any prerequisites other than Data Structures. All applicants must satisfy the Data Structures requirement before admittance.\n\nA student is more likely to be admitted by the school if the student's undergraduate degree is in computer science or a closely related field, and the student has completed a course in data structures* and\n\ntotal GRE greater than or equal to 290\nundergraduate GPA greater than or equal to 3.0 on a 4.0 scale AND\nnumber of backlogs less than or equal to 7\n\nApplicants not meeting these requirements may be admitted provisionally and contact\xa0Dr. Ajay Bandi\xa0at\xa0ajay@nwmissouri.edu.\nThe School of Computer Science and Information Systems reserves the right to make the final decision in accepting students to graduate degree candidacy. Criteria for admittance to the program and acceptance to degree candidacy may include academic qualifications and performance, letters of recommendatio ...
#  Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nAdmission Requirements \n\n\n\r\n\r\n            Candidates for the M.S. in Applied Computer Science should meet the following requirements:\r\n\nCompliance with all of the eligibility requirements of the Graduate School as set forth in the Graduate Catalog.\nAcceptance to graduate study by the Dean of the Graduate School.\nCompletion of a four-year undergraduate degree from an accredited college or university with an undergraduate grade point average of 3.00 on a 4.00 scale. Applicants are expected to have an undergraduate major or minor in a technical computing discipline, including coursework in\r\n\nData Structures\nDatabase Systems / Database Management Systems\nDiscrete Mathematics\nStatistics\n\nApplicants who do not satisfy these requirements may take undergraduate level courses to remove any prerequisites except for Data Structures. The applicant must satisfy the requirement for Data Structures to be admitted.\n\nMinimum GRE and TOEFL scores, as described below.\n\nBefore the program director is allowed to review your application, the Graduate school must verify your TOEFL score. The acceptable TOEFL score is set by the University as:\n\n213 for computer-based TOEFL\n71 for the Internet-Based TOEFL\n550 for pencil-and-paper-based TOEFL\n6.0 overall for IELTS\n105 for Duolingo English Test\nDetails for other acceptable test scores:\xa0\xa0https://www.nwmissouri.edu/admissions/international/englishproficiency.htm\n\nApplicants not meeting the TOEFL/IELTS requirement are not forwarded to the school for consideration.\nA student is more likely to be admitted by the school if\n\nThe student's undergraduate degree is in Computer Science or a closely related field AND\nthe student has successfully completed a course in data structures* AND\nTotal GRE >=290\xa0AND\nundergraduate GPA >=3.0, on a 4.0 scale AND\nnumber of backlogs <=7\n\n*Undergraduate courses in computer networks/network fundamentals and database management systems are required. Students admitted without these courses can take them at Northwest upon arrival for graduate study. However, students must have successfully completed a course in data structures prior to being admitted to the program.\nApplicants who do not meet these requirements may be admitted provisionally.\nThe School of Computer Science and Information Systems reserves the right of final decision in accepting students to graduate degree candidacy in the school. Criteria for admittance to the program and acceptance to degree candidacy may include academic qualifications and performance, letters of recommendation, number of applicants, and available resources.\nApplication Deadlines\nApplications and all transcripts must be submitted to the Office of Admissions by the following dates. International students should allow approximately two months from the time all application documents are received for notification of acceptance.\n\n\n\nSemester\nApplication Deadline\nDocument Deadline\n\n\n\n\nSummer\nMarch 1\nMarch 15\n\n\nFall\nJune 15\nJune 30\n\n\nSpring\xa0\nNovember 1\nNovember 15\n\n\n\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Lin ...
#  Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nCourse Descriptions\n\n\n\nComputer Science courses for the MSACS program are listed, each with a link to a detailed syllabus. This list includes prerequisite courses and some popular electives, along with the semesters that each is offered. Semesters offered may change. Check with the program advisor for up-to-date information.\n\n\n\nCourse No\nCourse Name\nHours\nSemester Offered\n\n\n\n\nPrerequisites (If not completed as an undergraduate)\n\n\n44-460\nDatabase Systems\n3\nFall, Spring\n\n\nRequired Courses\n\n\n44-542\nObject-Oriented Programming\n3\nFall, Spring\n\n\n44-560\nAdvanced Topics in Database Systems\n3\nFall, Spring, Summer\n\n\n44-563\nDeveloping Web Applications and\xa0Services\n3\nFall, Spring\n\n\n44-618\nProject Management in Business and Technology\n3\nSpring, Summer\n\n\n44-643\nMobile Computing: iOS\n3\nFall, Spring\n\n\n\xa0\xa0\xa0\xa0 (OR)\n\n\n44-644\nMobile Computing: Android\n3\nFall, Spring\n\n\n44-642\nApplication Design: Patterns And Frameworks\n3\nFall, Spring\n\n\n44-691\nCS\xa0Graduate Directed\xa0Project\xa0I\n3\nFall, Spring, Summer\n\n\n44-692\nCS\xa0Graduate\xa0Directed\xa0Project II\n3\nFall, Spring\n\n\n--\nAdvisor Approved Elective-I\n3\nFall, Spring\n\n\n--\nAdvisor Approved Elective-II\n3\nFall, Spring\n\n\nExamples of Elective Courses (Changes from Semester to Semester)\n\n\n44-517\nBig Data\n3\n--\n\n\n44-520\nWeb Mining\n3\n--\n\n\n44-599\nGenerative AI\n3\n--\n\n\n44-599\nAnalysis of Algorithm\n3\n--\n\n\n44-566\nMachine Learning\n3\n--\n\n\n44-613\nData Visualization\n3\n--\n\n\n44-525\nTheory and Implementation of Programming Languages\n3\n\n\n\n44-640\nInternet of Things\n3\n--\n\n\n44-643\nStudents who have taken 44-644 as their required course may take 44-643 as an elective.\n3\n--\n\n\n\xa0\xa0\xa0\xa0 (OR)\n\n\n44-644\nStudents who have taken 44-643 as their required course may take 44-644 as an elective.\n3\n--\n\n\n44-663\nApplication Development in C#.NET\n3\n--\n\n\n\nNote:\n\nElective courses are subjected to change every semester.\nThirty credit hours of graduate credits are required for completion of the M.S. in Applied Computer Science.\n\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/courses.htm', 'title': 'MS-ACS | School of Computer Science & Information Systems', 'description': 'Northwest Missouri State University Computer Science courses for the MS ...
#  Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nList of Graduate Directed Projects\n\n\n\n+ Expand Allâ€“ Collapse AllFrequently Asked QuestionsWhat is Graduate Directed project?Graduate Directed Project replaces the thesis requirement in the MS-ACS program. Over a two-semester period, students work with either internal (university) or external (business) clients to complete a project. The projects are very close to a real world software engineering experience. Students work in teams of three to ten, with a faculty mentor guiding the team through the entire software lifecycle. Students experience all aspects of software engineering including interviewing a client, domain analysis, requirements gathering, specification, design techniques including UML and ER diagrams, use cases, paper prototypes, iterative development, and user acceptance testing.\xa0 In addition, students develop valuable communications skills and learn how to properly interact with a client and how to work effectively in a team.Why do students have to take Graduate Directed Project?The two-semester Graduate Directed Project is in lieu of the normal thesis requirement for master’s level programs. Since our program is applied in nature and is designed to prepare you for the job market, engaging in a software development project better fits the goals of the MS-Applied Computer Science program.What are students required to do in Graduate Directed Project?Students are assigned to teams of 3-10 each. They are also assigned a faculty member to serve as their mentor. Projects are assigned to each team, and students normally are involved in all steps of a software development project, from gathering requirements from the client to deploying the finished product.Can students pick their own teams?A faculty committee assigns students to teams. Students may request to work with certain students, but there is no guarantee that their request will be honored. Many factors must be considered when teams are formed, including the balance of expertise and the background of the students involved.Can a student suggest a project?Anyone can suggest a project for a graduate directed project team. However, the proposal must be in written form and must supply sufficient detail for the faculty committee to make a decision.What if a team starts on their project in the spring and some team members are planning to continue in the summer, but others do not want to attend during the summer and want to wait until fall to complete the project.When teams are initially assigned, we make every effort to ensure that all team members have the same completion date in mind. If circumstances change, and some team members want to complete in the summer, with others completing in the fall, we will work out a solution. No student will be forced to attend in the summer, or to wait until fall, for completion of the project.How are clients chosen?We solicit clients from our own school, from other offices in the university, and from companies and businesses off-campus.\xa0 Potential clients submit a proposal, and a faculty committee selects those proposals that seem to be suitable for a Graduate Directed Project team.List Of Projects\n\n2023-24\n2022-23\n2021-22\n2020-21\n2019-20\n2018-19\n2017-18\n2016-17\n2015-16\n2014-15\n2013-14\n\n\n\n\n2012-13\n2011-12\n2010-11\n2009-10\n2008- ...
#  Document(page_content="\n\n\n\n\n\n\nSchool of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nResearch and Independent Studies\n\n\n\nResearch Projects\nThe MS-ACS program is not a thesis based program and hence there is no research work as a part of the program. However, students can always consult with the faculty here, who keep working on individual research projects continuously. The student may get a chance to work on that research work with the faculty.\nHowever, all the students have to explore and work on graduate directed projects as part of their program. The list of projects finished by earlier students can be found at the projects page link.\nIndependent Studies\nMS-ACS program provides flexibility to the students to work on an independent project in their area of interest. The student can work on any project of their interest using technology, under the guidance of a faculty and can finish this course within the time allotted. This course provides the opportunity for students to explore any technology or project that is not available in the program as of now. This is considered as an independent course, post completion of this course, 1 hour will be added to the student's degree audit.\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/current/research.htm', 'title': 'School of Computer Science & Information Systems | Northwest', 'description': 'The official website of Northwest Missouri State University located in Maryville, Missouri.', 'language': 'en'}),
#  Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nFinancial Assistance\n\n\n\nNorthwest’s tuition is much less than that of many other institutions. New international students who are admitted receive a $500 scholarship for their first semester of study.\xa0\nCost Calculations:\n\nCost Calculator\n\n\xa0\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/finaid.htm', 'title': 'MS-ACS | School of Computer Science & Information Systems | Northwest', 'description': 'The official website of Northwest Missouri State University located in Maryville, Missouri.', 'language': 'en'}),
#  Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nOn-campus Employment\n\n\n\nWe have a limited number of graduate assistantships (GAs). GA positions include a tuition waiver and a monthly stipend. We also have some hourly employee positions which are available to both graduate and undergraduates. Hourly employee positions do not include a tuition waiver, but they provide you with some income and experience working in the field.\xa0However, we cannot guarantee any employment, which is why we require financial information and proof of your ability to cover your own expenses before we consider your application.\nIf you are an international student, please be aware that it is very hard for international students to find employment during their first semester. If you do well during your first semester on campus, then it may be possible to find an assistantship for the second semester.\nSee Financial Assistance page for details.\nOn-Campus Jobs\n\nGraduate Assistantship\nStudent Employment\nCampus Dining\n\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/on-campus-employment.htm', 'title': 'MS-ACS | School of Computer Science & Information Systems | Northwest', 'description': 'The official website of Northwest Missouri State University located in Maryville, Missouri.', 'language': 'en'}),
#  Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nInternship and CPT(Curricular Practical Training)\n\n\n\nStudents in the MS-ACS program are encouraged to obtain summer internships. A summer internship will provide you with an opportunity to see how the concepts and skills learned in the classroom translate to real projects in industry.\nIt is the student's responsibility to make the appropriate contacts to obtain an internship. An internship may be either on campus or off-campus. A student may or may not be paid for internship work. Students may or may not earn academic credit for an internship. Students who desire academic credit will sign up for a one-credit-hour section of 44-699 Graduate Internship in Information Technology or 44-599 Special Projects - Independent Study Computer Science. For details about 44-699 or 44-599, see CSIS Internship Policies and Procedures\xa0.\nSPECIAL NOTES FOR INTERNATIONAL STUDENTS WHO WANT SUMMER INTERNSHIPS:\nThe School of Computer Science and Information Systems at Northwest Missouri State University participates in the CPT (curricular practical training) program for international students. Note some restrictions on CPT:\n\nThe School of Computer Science and Information Systems will support requests for CPT for the summer semester. Fall and spring CPT requests may\xa0be granted, depending on the circumstances.\nCPT requires that a student\xa0be enrolled full time for one academic year (two semesters) before becoming eligible for CPT. This means that students enrolling for the first time in the fall are eligible for CPT the following summer. However, students enrolling for the first time in the spring are not eligible for CPT until they have completed an additional semester of study.\nCPT guidelines require that you enroll in an internship course. MS-ACS students will enroll in a one-credit-hour section of 44-699 Graduate Internship in Information Technology\n\nThe following documents provide more details regarding CPT and internship policies and procedures:\n\nStudent Procedure (Sample )\nEmployer Procedure (Sample )\nAcademic Advisor Letter (Sample )\nFaculty Procedure (Sample )\nJob Offer Letter (Sample )\nCSIS Internship Policies and Procedures\xa0For all students, both international and non-international\nWeekly Log templateThis is a sample template; your instructor may require that you use a different template.\n\nHelp for Job\xa0Interviews\nTo learn more about interviewing and creating résumés, enroll in 44-296 Professional Development Seminar. This is a one-credit hour, undergraduate course that will prepare you to interview for internships and full-time jobs. You will also learn how to create effective résumés. This course is NOT required and does NOT count toward the MS in Applied Computer Science program, but it is highly recommended.\nIn the meantime, here are some helpful hints that might be of use. These are general documents and apply to a wide variety of situations. You must adapt the suggestions to fit the situation. Applying for a student job on campus is not the same as applying for a full-time job upon graduation. Basic rules apply to both situations, but details may differ. Use these documents as a guideline.\n\nA Sample Resume\nInterview_tipsbasics.doc\xa0\nInterviewDoAndDont.doc\xa0\n\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedul ...
#  Document(page_content="\n\n\n\n\n\n\nOrganizations | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\n\n\n\nSchool of Computer Science and Information Systems\n\n\n  \n\n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nAbout Us\nDegree Programs\nFaculty & Staff\nOrganizations\nEvents\nCareer Information\nContact Us\nRelated Links\n\nApply Now!\nFinancial Aid & Scholarships\nAlumni & Support\n\n\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS\nStudent Organizations\n\n\n\nGet InvolvedHalf of all Northwest students participate in a student organization. With over 200 recognized groups to choose from, explore your passions while discovering new interests along the way.\nSearch All Student OrgsAssociation of Computing Machinery\nACM promotes a greater interest in computers and applications as well as providing a means of communication for persons sharing an interest in computers.\nView ACM Website\nAssociation of Computing Machinery - Graduate Student Chapter\n ACM-Graduate is a special interest group for ACM graduate student members. Visit us at:\n\n\n\n\n\nSponsors: Denise Case, Ajay Bandi\nACM-G Members Login\nBeta Chapter, Pi Omega Pi\n This national business teacher education honor society honors students with high scholastic ability in business education. Eligibility requirements include interest in becoming a business educator; completion of three semester of college courses, including at least 15 hours in business and/or education subjects; and a 3.00 GPA in business and education courses. Seniors are eligible to apply for the C & C Taylor Scholarship awarding up to $11,000 in scholarship annually.\nSponsors: Crystal Combs\nView Pi Omega Pi Website\nCyber Defense Club\nCyber Defense Club is a computer science organization focused on giving students a hands-on learning experience and preparing them for cyber defense competitions.\nSponsor: Jerry Qin\nVIEW cyber defense club WEBSITE\nEtA Gamma Chapter, Delta Mu Delta\nDelta Mu Delta is the national honor society in business administration. The purposes of DMD are to promote higher scholarship in training for business and to recognize and reward scholastic attainment in business subjects. Students of junior standing majoring in Business Technology and Management Information Systems and in the top 20 percent of their class will be invited for membership.\nSponsors: Casey Abington,\xa0Jeff Nickerson\nUpsilon Pi Epsilon\nThe mission of UPE is to recognize academic excellence at both the undergraduate and graduate levels in the computing and information disciplines.\nSponsors: Ajay Bandi, Diana Linville\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n\nTop\n\n\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/csis/orgs/index.htm', 'title': 'Organizations | School of Computer Science & Information Systems | Northwest', 'description': 'The official website of Northwest Missouri State University located in Maryville, Missouri.', 'language': 'en'}),
#  Document(page_content='\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nFrequently Asked Questions\n\n\n\n+ Expand Allâ€“ Collapse AllFor international students:I have received my visa -- what next? This document is prepared by the International Involvement Center (IIC). It provides much useful information regarding the next steps after receiving your visa. For more information contact Connie Murphy and IIC (intlprog@nwmissouri.edu).Do I have to purchase health insurance in the United States? What vaccines do I need to have before I arrive?Students must purchase health insurance at Northwest. For the year 2022-2023, the annual cost is around $1,500.00.Regarding the Vaccines, you need to at least complete MMR (1st dose) and if you live on campus you need to even take Meningitis.For all students, both international and non-international:How does the Master of Science in Applied Computer Science differ from programs in Computer Science?The MS in Applied Computer Science at Northwest Missouri State University differs from other programs in computer science in some significant ways:\nThe focus of this program is to prepare students to enter a very competitive job market by increasing their skills in high-demand areas and emerging technologies. Many master\'s programs in computer science have a more theoretical basis because the aim of the program is to prepare students to go on for more graduate work at the Ph.D. level. Our program covers theoretical concepts, but students also gain hands-on experience and have strong technical skills when they graduate from the program.\nOur program requirements include six credit hours of course work (two courses) that look at information technology issues from a business perspective. In many computer science programs there is no coverage of business issues.\nIn place of the thesis requirement required by many programs, our program requires a year-long, six-credit hour project that provides students with the opportunity to apply their knowledge to a software project.\nThe primary goals of this program are to produce graduates that\n\nhave a high degree of competence in areas of high-demand and emerging technologies\nhave good project management skills and will understand fundamental business concepts, as related specifically to information technology\nhave experience in design and implementation of a large project\nknow how to work in teams\nhave good written communication and presentation skills\n\nTo ensure that our program meets these goals, we get regular feedback from potential employers. Feedback for this program has been very positive with employers confirming that we have the right mix of theory and practice. They have been particularly positive about the inclusion of the two business-related courses because they frequently encounter problems with "techies" being unable to communicate with others in the organization.What work opportunities are available? Can I get a graduate assistantship?\n\nThere are many work opportunities available on campus for students few among them are office Assistants, Student ambassadors, Teaching assistants, Campus Dine-in jobs, Graduate Assistants, and many more. Every student would be eligible for a Graduate Assistantship based on their performance in the semesters, proactiveness, and active participation in the class.\nIn any semester if you get a full gr ...
#  Document(page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nContact Us\n\n\n\nIf you ever have any questions about the Masters in Applied Computer Science program, please use the contact information below.\nThe school's office is open from 8 a.m. - 5 p.m., Monday - Friday.\nAjay Bandi, Ph.D.Associate Professor andProgram Coordinator, MS-Applied Computer ScienceSchool of Computer Science and Information SystemsNorthwest Missouri State University2250 Colden Hall800 University DriveMaryville, MO-64468Email: ajay@nwmissouri.edu (or) msacs@nwmissouri.eduOffice: 660.562.1199\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/contact.htm', 'title': 'MS-ACS | School of Computer Science & Information Systems | Northwest', 'description': 'The official website of Northwest Missouri State University located in Maryville, Missouri.', 'language': 'en'})]

# %% [markdown]
# - **TokenTextSplitter**: This class is used to split text into chunks, typically to prepare it for processing by language models or other natural language processing tasks.
# - **text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)**: Initializes an instance of `TokenTextSplitter` with a chunk size of 512 tokens and an overlap of 24 tokens between consecutive chunks.
# - **documents = text_splitter.split_documents(data)**: Splits the input `data` (presumably a collection of text documents) into chunks of the specified size and overlap, storing the resulting chunks in the `documents` variable.
#
# This approach is useful for breaking down large text documents or datasets into manageable pieces that can be processed more efficiently by downstream tasks or models.

# %%
text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
documents = text_splitter.split_documents(data)

# %%
print(documents[0])
print(documents[1])
print(documents[2])
# Out:
# page_content="\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\xa0\n\xa0\n\n\n » CSIS\nWelcome to Masters in Applied Computer Science\n\n\n\nAt Northwest, we are dedicated towards the development of future leaders in the information technology (IT) industry. Our highly qualified faculty members collaborate and work together to educate students who come to obtain a quality education. We provide appropriate technological and instructional resources for our students to help them succeed in the IT job market worldwide. Northwest is also committed towards the personal and social development of its students by providing opportunities for our students to interact with others in a successful, ethical way.Prospective MS-ACS StudentsAdmissions information for prospective international students.MSACS on FacebookFollow the Masters in Applied Computer Science program on Facebook!\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n" metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/', 'title': 'MS-ACS | School of Computer Science & Information Systems | Northwest', 'description': 'Northwest Missouri State University is committed to developing future leaders in the IT industry through the Masters in Applied Computer Science program.', 'language': 'en'}
# page_content='\n\n\n\n\n\n\nMS-ACS | School of Computer Science & Information Systems | Northwest\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to Main Content\n\n\n\nSchool of Computer Science and Information Systems\n  \n\n\n\nClose \n\n\n\n\n\n\n Search Term   \n\n\n\n\nWelcome\nWhy MS-ACS?\nProgram Description\nAdmission Requirements\nCourse Descriptions\nCurrent Students\n\nWriting Samples\nGraduate Directed Project\nResearch Projects / Independent Studies\n\n\nFinancial Assistance / Cost Calculations\nEmployment Opportunities\n\nOn-campus Employment\nInternship and CPT\n\n\nOrganizations\nFrequently Asked Questions\nContact Us\n\n\n\n\n\n\n\n\xa0\n\n\n » CSIS » MS-ACS\nWhy MS-Applied Computer Science Program?\n\n\n\nThe Program\nThe Master of Science in Applied Computer Science offers students with strong undergraduate background in a technical computing discipline an opportunity to increase their technical expertise and to complement that expertise with fundamental business concepts related specifically to information technology. The term Applied Computer Science was carefully chosen. The practical skills developed for a wide variety of high-demand areas, as well as the firm conceptual foundation provided by the program, combine to create graduates that are well-prepared to succeed in a very competitive job market.\nThe M.S. Applied Computer Science program has a STEM CIP code 11.0701 that currently allows an extra 24 months of OPT (Optional Practical Training) extension after completion of 12 month OPT period. Visit U.S. Citizenship and Immigration Services for updates.\nFor more details about the program, see Program Description.\nOverview of Program, School and University\n\nThe average class size at Northwest is 27.\nStudent to faculty ratio is 22 to 1.\nBetween 75 and 375 graduate students are normally enrolled in the M.S. in Applied Computer Science program.\nNorthwest Missouri State University is home to the Missouri Arboretum, providing a beautiful environment for all members of the university community.\nNorthwest is considered one of the safest campuses in the nation.\n\nComputing Facilities\nThe Electronic Campus gives students access to the Internet and to the Missouri Research and Education Network. Computer languages supported on the network include \xa0Java, C#, C++, Perl, Smalltalk, Node JS, Android Studio, and Swift.\xa0Databases include SQL, NoSQL, SQL Server, MongoDB, and Oracle 12c.\nAll students have access to specialized computer laboratories housed in the Cold' metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/about.htm', 'title': 'MS-ACS | School of Computer Science & Information Systems | Northwest', 'description': 'The official website of Northwest Missouri State University located in Maryville, Missouri.', 'language': 'en'}
# page_content=" SQL Server, MongoDB, and Oracle 12c.\nAll students have access to specialized computer laboratories housed in the Colden Hall Computing Complex. In addition, every full-time student is provided with a laptop by the University. There are multiple wireless access points on campus.\nGraduate Research\nAll graduate students in the MS-Applied Computer Science program are required to complete a two-semester software development project during their last two semesters of their study. For a list of recent projects, see the projects page.\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n" metadata={'source': 'https://www.nwmissouri.edu/csis/msacs/about.htm', 'title': 'MS-ACS | School of Computer Science & Information Systems | Northwest', 'description': 'The official website of Northwest Missouri State University located in Maryville, Missouri.', 'language': 'en'}

# %% [markdown]
# - **ChatOpenAI**: This class is used to interact with OpenAI's chat models. In this case, it's initialized with parameters like `temperature=0` and `model_name="gpt-3.5-turbo-0125"`.
# - **LLMGraphTransformer**: This class is used to transform text documents into graph documents using a language model (LLM).
# - **Neo4jGraph**: This class represents a connection to a Neo4j graph database.
#
#
# The code first initializes the language model (`llm`) and the transformer (`llm_transformer`) to convert text documents (`documents`) into graph documents. Then, it initializes a `Neo4jGraph` instance (`graph`) and adds the transformed graph documents to the Neo4j database using the `add_graph_documents` method.
#
# This approach integrates natural language processing with graph database operations, enabling the creation of structured graph representations from unstructured text data.

# %%
llm=ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-0125") # gpt-4-0125-preview occasionally has issues
llm_transformer = LLMGraphTransformer(llm=llm)

# Following needs to be used only first time to load the data. It took 3m 44s
graph_documents = llm_transformer.convert_to_graph_documents(documents)
# graph.add_graph_documents(
#     graph_documents,
#     baseEntityLabel=True,
#     include_source=True
# )

# %%
print (documents[5])
print(graph_documents[5])
# Out:
# page_content=" TOEFL\n6.0 overall for IELTS\n\nInternational information flyer for the M.S. Applied Computer Science program\xa0»\nMore information for International StudentsRight size. Right price.We understand college is a big investment. Why not attend a school that is invested in you?What will it cost? Scholarships and aid Check out our FAFSA guide\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n" metadata={'source': 'https://www.nwmissouri.edu/academics/graduate/masters/applied-computer-science.htm', 'title': 'Applied Computer Science | Graduate Program', 'description': "Northwest Missouri State University's Master of Science in Applied Computer Science is a 16-month program that offers a hands-on, professional education in today's high demand areas.", 'language': 'en'}
# nodes=[Node(id='Toefl', type='English language proficiency test'), Node(id='Ielts', type='English language proficiency test'), Node(id='M.S. Applied Computer Science Program', type='Program'), Node(id='Northwest Missouri State University', type='University')] relationships=[Relationship(source=Node(id='Toefl', type='English language proficiency test'), target=Node(id='M.S. Applied Computer Science Program', type='Program'), type='REQUIRED_FOR'), Relationship(source=Node(id='Ielts', type='English language proficiency test'), target=Node(id='M.S. Applied Computer Science Program', type='Program'), type='REQUIRED_FOR'), Relationship(source=Node(id='M.S. Applied Computer Science Program', type='Program'), target=Node(id='Northwest Missouri State University', type='University'), type='OFFERED_AT')] source=Document(page_content=" TOEFL\n6.0 overall for IELTS\n\nInternational information flyer for the M.S. Applied Computer Science program\xa0»\nMore information for International StudentsRight size. Right price.We understand college is a big investment. Why not attend a school that is invested in you?What will it cost? Scholarships and aid Check out our FAFSA guide\n\n\n\n\n\nReady to be a Bearcat?\n\nRequest Info\nSchedule a Visit\nApply Now\n\n\n\n\n\n\n\n\n\n\n\n\n\nNorthwest Missouri State University 800 University Drive Maryville, MO 64468 USA\n660.562.1212\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampus Links\n\nAcademic Calendar\nEmergency Alert Sign Up\nNews and Events\nMaps and Tours\nConsumer Information\n\n Report an Incident\n\nAffiliates\n\nAlumni\nAthletics\nChildren/Lab School\nJobs at Northwest\nMake a Gift\nNorthwest Online\nNorthwest-Kansas City\n\n\n\n\n\n\n\n\n\nContact\nFeedback\nPolicies\n\n\n\n© 2022 Northwest Missouri State University. All rights reserved.\n\n\nNorthwest Missouri State University is an equal opportunity/access/affirmative action/pro-disability and veteran employer and does not discriminate on the basis of sex in our education programs or activities, pursuant to Title IX and 34 CFR Part 106. For more information, visit Northwest's Non-Discrimination Policy.\n\n\n Top\n\n\n\n", metadata={'source': 'https://www.nwmissouri.edu/academics/graduate/masters/applied-computer-science.htm', 'title': 'Applied Computer Science | Graduate Program', 'description': "Northwest Missouri State University's Master of Science in Applied Computer Science is a 16-month program that offers a hands-on, professional education in today's high demand areas.", 'language': 'en'})

# %% [markdown]
# The `showGraph` function takes an optional `Cypher `query string as input (defaulting to a predefined query), establishes a connection to `Neo4j` using credentials from environment variables, executes the query to retrieve graph data, and then visualizes it using a `GraphWidget`. The widget allows interactive exploration of the graph nodes and relationships directly within the notebook environment, making it easy to analyze and understand graph structures and connections.

# %%
# directly show the graph resulting from the given Cypher query
default_cypher = "MATCH (s)-[r:!MENTIONS]->(t) RETURN s,r,t LIMIT 50"

def showGraph(cypher: str = default_cypher):
    # create a neo4j session to run queries
    driver = GraphDatabase.driver(
        uri = os.environ["NEO4J_URI"],
        auth = (os.environ["NEO4J_USERNAME"],
                os.environ["NEO4J_PASSWORD"]))
    session = driver.session()
    widget = GraphWidget(graph = session.run(cypher).graph())
    widget.node_label_mapping = 'id'
    #display(widget)
    return widget

showGraph()
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %% [markdown]
# The `Neo4jVector.from_existing_graph()` method is used to create a vector index within a Neo4j database. It integrates embeddings from OpenAI's models, facilitating efficient search and retrieval operations based on both textual content and embedding similarities.
#
# ### Key Components:
#
# - **LangChain Components**:
#   - **Neo4jVector**: This class from LangChain Community is designed to manage vector indexes within Neo4j, enabling storage and retrieval of embeddings associated with graph nodes.
#   - **OpenAIEmbeddings**: This class from LangChain OpenAI provides tools for generating embeddings using OpenAI's models.
#
# - **Initialization Parameters**:
#   - **OpenAIEmbeddings()**: Initializes the use of OpenAI's models to generate embeddings.
#   - **search_type="hybrid"**: Specifies a hybrid search approach, leveraging both textual content and embedding similarities for efficient querying.
#   - **node_label="Document"**: Specifies that nodes labeled "Document" in the Neo4j graph will store document-related information.
#   - **text_node_properties=["text"]**: Defines the property name(s) within "Document" nodes where textual content is stored.
#   - **embedding_node_property="embedding"**: Specifies the property name where embeddings are stored within the "Document" nodes.
#
# ### Usage Scenario:
#
# This setup is useful in scenarios where you want to store and query documents based on both their textual content and their embeddings. For example, you can store documents in Neo4j, extract their embeddings using OpenAI's models, and then use this vector index to efficiently search for documents based on their semantic similarity to a given query or to other documents in the database.
#
# This approach leverages the capabilities of Neo4j for graph-based storage and retrieval, coupled with advanced embedding techniques from OpenAI, providing a powerful toolset for managing and analyzing textual data within a graph database environment.

# %%
vector_index = Neo4jVector.from_existing_graph(
    OpenAIEmbeddings(),
    search_type="hybrid",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding"
)

# %% [markdown]
# ### Retriever Setup:
#
# The code snippet performs the following actions:
#
# 1. **Create Fulltext Index**:
#    - The `graph.query()` statement creates a fulltext index named `entity` if it does not already exist. This index is applied to nodes labeled `__Entity__` and indexes the `id` property of these nodes for efficient querying.
#
# 2. **Entity Data Model**:
#    - The `Entities` class, derived from `BaseModel`, defines a structured representation for identifying information about entities extracted from text.
#    - **Names**: A list of strings representing entities such as courses, professors, requirements, or project entities found in the text.
#
# 3. **Chat Prompt Template**:
#    - The `ChatPromptTemplate.from_messages()` method initializes a prompt template for interacting with users.
#    - The prompt consists of a system message informing the user about the extraction task and a human message specifying the format for input to extract information.
#
# 4. **Entity Chain**:
#    - The `prompt | llm.with_structured_output(Entities)` constructs an entity extraction pipeline using LangChain:
#      - **Prompt**: Provides instructions to the user on how to input questions or text for entity extraction.
#      - **LLM (Language Model)**: Processes the input using OpenAI's language model to extract structured entities as defined by the `Entities` class.
#
# ### Usage:
#
# This setup is designed to facilitate the extraction of entities from text input in a structured and systematic manner. The fulltext index ensures that entity nodes in the Neo4j graph are efficiently indexed, allowing for quick retrieval of relevant entities based on their `id` property. The `Entities` data model and the prompt template guide the interaction with users, ensuring that the extraction process is clear and consistent.
#
# This approach leverages natural language processing and graph database capabilities to manage and analyze textual data effectively, supporting tasks such as information extraction, entity linking, and knowledge base population within a broader application or system.

# %%
# Retriever

graph.query(
    "CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]")

# Extract entities from text
class Entities(BaseModel):
    """Identifying information about entities."""

    names: List[str] = Field(
        ...,
        description="All the courses, requirements, or business entities that "
        "appear in the text",
    )

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are extracting course, professors, requirements, project entities from the text.",
        ),
        (
            "human",
            "Use the given format to extract information from the following "
            "input: {question}",
        ),
    ]
)

entity_chain = prompt | llm.with_structured_output(Entities)

# %%
def generate_full_text_query(input: str) -> str:
    """
    Generate a full-text search query for a given input string.

    This function constructs a query string suitable for a full-text search.
    It processes the input string by splitting it into words and appending a
    similarity threshold (~2 changed characters) to each word, then combines
    them using the AND operator. Useful for mapping entities from user questions
    to database values, and allows for some misspelings.
    """
    full_text_query = ""
    words = [el for el in remove_lucene_chars(input).split() if el]
    for word in words[:-1]:
        full_text_query += f" {word}~2 AND"
    full_text_query += f" {words[-1]}~2"
    return full_text_query.strip()

# Fulltext index query
def structured_retriever(question: str) -> str:
    """
    Collects the neighborhood of entities mentioned
    in the question
    """
    result = ""
    entities = entity_chain.invoke({"question": question})
    for entity in entities.names:
        response = graph.query(
            """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
            YIELD node,score
            CALL {
              WITH node
              MATCH (node)-[r:!MENTIONS]->(neighbor)
              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output
              UNION ALL
              WITH node
              MATCH (node)<-[r:!MENTIONS]-(neighbor)
              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output
            }
            RETURN output LIMIT 50
            """,
            {"query": generate_full_text_query(entity)},
        )
        result += "\n".join([el['output'] for el in response])
    return result

# %%
def retriever(question: str):
    print(f"Search query: {question}")
    structured_data = structured_retriever(question)
    unstructured_data = [el.page_content for el in vector_index.similarity_search(question)]
    final_data = f"""Structured data:
{structured_data}
Unstructured data:
{"#Document ". join(unstructured_data)}
    """
    return final_data

# %%
# Condense a chat history and follow-up question into a standalone question
_template = """Given the following conversation and a follow up question, rephrase the follow up question to be a standalone question,
in its original language.
Chat History:
{chat_history}
Follow Up Input: {question}
Standalone question:"""  # noqa: E501
CONDENSE_QUESTION_PROMPT = PromptTemplate.from_template(_template)

def _format_chat_history(chat_history: List[Tuple[str, str]]) -> List:
    buffer = []
    for human, ai in chat_history:
        buffer.append(HumanMessage(content=human))
        buffer.append(AIMessage(content=ai))
    return buffer

_search_query = RunnableBranch(
    # If input includes chat_history, we condense it with the follow-up question
    (
        RunnableLambda(lambda x: bool(x.get("chat_history"))).with_config(
            run_name="HasChatHistoryCheck"
        ),  # Condense follow-up question and chat into a standalone_question
        RunnablePassthrough.assign(
            chat_history=lambda x: _format_chat_history(x["chat_history"])
        )
        | CONDENSE_QUESTION_PROMPT
        | ChatOpenAI(temperature=0)
        | StrOutputParser(),
    ),
    # Else, we have no chat history, so just pass through the question
    RunnableLambda(lambda x : x["question"]),
)

# %%
# Answer the question based only on the following context
template = """State whether the given prompt is TRUE or FALSE based only on the following context:
{context}

Question: {question}
Use natural language and be concise.
Answer:"""
prompt = ChatPromptTemplate.from_template(template)

chain = (
    RunnableParallel(
        {
            "context": _search_query | retriever,
            "question": RunnablePassthrough(),
        }
    )
    | prompt
    | llm
    | StrOutputParser()
)

# %%
chain.invoke({"question": "Is there a specific admission requirement for the MS-ACS program?"})
# Out:
# Search query: Is there a specific admission requirement for the MS-ACS program?
# 'TRUE'

# %%
#True Positive
chain.invoke({"question": "Is the minimum score for Dulingo 110 ?"})
# Out:
# Search query: Is the minimum score for Dulingo 110 ?
# 'Yes, the minimum required Duolingo score to get admission is 110.'

# %%
#True Negative
chain.invoke({"question": "Is a  score of 100 not sufficient for Dulingo ?"})
# Out:
# Search query: Is a  score of 100 not sufficient for Dulingo ?
# 'A score of 100 on the Duolingo English Test is not sufficient for admission to the M.S. in Applied Computer Science program at Northwest Missouri State University.'

# %%
# False Negative
chain.invoke({"question": "Is a  score of 115 not sufficient for Dulingo ?"})
# Out:
# Search query: Is a  score of 115 not sufficient for Dulingo ?
# 'A score of 115 is sufficient for Duolingo.'

# %%
# False Positives
chain.invoke({"question": "Is a  score of 105 sufficient for Dulingo ?"})
# Out:
# Search query: Is a  score of 105 sufficient for Dulingo ?
# 'Yes, a score of 105 is sufficient for Duolingo.'

# %%
chain.invoke({"question": "Who is the Advisor for MSACS program?"})
# Out:
# Search query: Who is the Advisor for MSACS program ?
# 'Ajay Bandi, Ph.D.'

# %%
chain.invoke({"question": "What is his email ?"})
# Out:
# Search query: What is his email ?
# "Ajay Bandi's email is ajay@nwmissouri.edu or msacs@nwmissouri.edu."

# %%
chain.invoke({"question": "What are the required courses ?"})
# Out:
# Search query: What are the required courses ?
# 'The required courses for the MSACS program are:\n- Database Systems\n- Object-Oriented Programming\n- Advanced Topics in Database Systems\n- Developing Web Applications and Services\n- Project Management in Business and Technology\n- Mobile Computing: iOS or Mobile Computing: Android\n- Application Design: Patterns And Frameworks\n- CS Graduate Directed Project I\n- CS Graduate Directed Project II\n- Advisor Approved Elective-I\n- Advisor Approved Elective-II'

# %%
chain.invoke({"question": "Is fire hot tell me T or F?"})
# Out:
# Search query: Is fire hot tell me T or F?
# 'TRUE'

# %%
ans = []
with open('seccat.txt', 'r') as file:
  for line in file:
    question = line.strip()
    try:
      answer = chain.invoke(({"question": question}))
    except Exception as e:
      answer = "err"
    print( " answer: " + answer)
    ans.append(answer)

with open("seccatans.txt", 'w') as f:
    for item in ans:
        f.write("%s\n" % item)
# Out:
# Search query: Is the sky blue on a clear day?
#  answer: TRUE
# Search query: Are apples typically red, green, or yellow?
#  answer: FALSE
# Search query: Are dogs commonly kept as pets?
#  answer: FALSE
# Search query: Does the sun rise in the east?
#  answer: TRUE
# Search query: Is ice cold?
#  answer: FALSE
# Search query: Do humans need oxygen to survive?
#  answer: TRUE
# Search query: Is the Earth round?
#  answer: FALSE
# Search query: Do fish live in water?
#  answer: TRUE
# Search query: Are cars used for transportation?
#  answer: TRUE
# Search query: Is chocolate sweet?
#  answer: FALSE
# Search query: Is fire hot?
#  answer: Not enough information to determine.
# Search query: Do birds have feathers?
#  answer: TRUE
# Search query: Is the moon visible at night?
#  answer: TRUE
# Search query: Is summer usually warmer than winter?
#  answer: TRUE
# Search query: Is a marathon 26.2 miles long?
#  answer: TRUE
# Search query: Are elephants larger than mice?
#  answer: FALSE
# Search query: Is rain wet?
#  answer: FALSE
# Search query: Are trees green in the summer?
#  answer: FALSE
# Search query: Do cows produce milk?
#  answer: FALSE
# Search query: Is honey made by bees?
#  answer: TRUE
# Search query: Is coffee typically served hot?
#  answer: TRUE
# Search query: Are strawberries red?
#  answer: FALSE
# Search query: Is a violin a string instrument?
#  answer: TRUE
# Search query: Do airplanes fly?
#  answer: TRUE
# Search query: Is gold a precious metal?
#  answer: TRUE
# Search query: Are kangaroos native to Australia?
#  answer: FALSE
# Search query: Is the Great Wall of China in China?
#  answer: TRUE
# Search query: Is Mount Everest the highest mountain in the world?
#  answer: FALSE
# Search query: Do humans have five senses?
#  answer: FALSE
# Search query: Is Spanish a language spoken in Spain?
#  answer: TRUE
# Search query: Is Paris the capital of France?
#  answer: FALSE
# Search query: Are tigers carnivores?
#  answer: FALSE
# Search query: Is the Pacific Ocean the largest ocean?
#  answer: FALSE
# Search query: Are bananas yellow when ripe?
#  answer: FALSE
# Search query: Is an octopus a marine animal?
#  answer: TRUE
# Search query: Are polar bears native to the Arctic?
#  answer: FALSE
# Search query: Is the heart an organ in the human body?
#  answer: TRUE
# Search query: Are computers used for processing data?
#  answer: TRUE
# Search query: Is a maple leaf a symbol on the Canadian flag?
#  answer: TRUE
# Search query: Is the piano a musical instrument?
#  answer: FALSE
# Search query: Is New York City in the United States?
#  answer: TRUE
# Search query: Is water composed of hydrogen and oxygen?
#  answer: FALSE
# Search query: Is the Amazon River in South America?
#  answer: TRUE
# Search query: Are roses a type of flower?
#  answer: TRUE
# Search query: Is a circle a round shape?
#  answer: TRUE
# Search query: Are diamonds made of carbon?
#  answer: TRUE
# Search query: Is sushi a Japanese dish?
#  answer: TRUE
# Search query: Is a dolphin a mammal?
#  answer: FALSE
# Search query: Is wool obtained from sheep?
#  answer: FALSE
# Search query: Is the capital of Australia Sydney?
#  answer: FALSE
# Search query: Do penguins live at the North Pole?
#  answer: FALSE
# Search query: Is an ostrich able to fly?
#  answer: FALSE
# Search query: Is the Sahara Desert in South America?
#  answer: FALSE
# Search query: Do whales have gills?
#  answer: FALSE
# Search query: Is spinach a fruit?
#  answer: FALSE
# Search query: Is the speed of light slower than the speed of sound?
#  answer: FALSE
# Search query: Is Beethoven a famous painter?
#  answer: FALSE
# Search query: Do camels have one hump?
#  answer: FALSE
# Search query: Is a tomato a vegetable?
#  answer: FALSE
# Search query: Is Pluto still classified as a planet?
#  answer: FALSE
# Search query: Do kangaroos lay eggs?
#  answer: FALSE
# Search query: Is the Eiffel Tower in Berlin?
#  answer: FALSE
# Search query: Is the currency of Japan the Yuan?
#  answer: FALSE
# Search query: Is Africa the smallest continent?
#  answer: FALSE
# Search query: Do zebras have spots?
#  answer: FALSE
# Search query: Is the capital of Italy Madrid?
#  answer: FALSE
# Search query: Do elephants live in Antarctica?
#  answer: FALSE
# Search query: Is the moon made of cheese?
#  answer: FALSE
# Search query: Do airplanes travel underwater?
#  answer: FALSE
# Search query: Is the Statue of Liberty in Los Angeles?
#  answer: FALSE
# Search query: Is milk green?
#  answer: FALSE
# Search query: Is chocolate made from vanilla beans?
#  answer: FALSE
# Search query: Is a rainbow circular in shape?
#  answer: FALSE
# Search query: Is the main language in Brazil Spanish?
#  answer: FALSE
# Search query: Are dolphins fish?
#  answer: FALSE
# Search query: Is ice cream usually served hot?
#  answer: FALSE
# Search query: Is cotton obtained from animals?
#  answer: FALSE
# Search query: Is Mount Fuji in India?
#  answer: FALSE
# Search query: Are grapes typically blue?
#  answer: FALSE
# Search query: Is a square a type of triangle?
#  answer: FALSE
# Search query: Are carrots purple when ripe?
#  answer: FALSE
# Search query: Is the main ingredient in bread sugar?
#  answer: FALSE
# Search query: Is a kangaroo a type of bird?
#  answer: FALSE
# Search query: Are clouds found underground?
#  answer: FALSE
# Search query: Is the main color of the sun green?
#  answer: FALSE
# Search query: Are leaves blue in the summer?
#  answer: FALSE
# Search query: Is a tiger a type of insect?
#  answer: FALSE
# Search query: Are strawberries typically blue?
#  answer: FALSE
# Search query: Is a violin a type of drum?
#  answer: FALSE
# Search query: Are roses typically green?
#  answer: FALSE
# Search query: Is the Pacific Ocean the smallest ocean?
#  answer: FALSE
# Search query: Are polar bears native to the Sahara Desert?
#  answer: FALSE
# Search query: Is sushi an Italian dish?
#  answer: FALSE
# Search query: Is a dolphin a type of fish?
#  answer: FALSE
# Search query: Is wool obtained from cows?
#  answer: FALSE
# Search query: Is New York City the capital of the United States?
#  answer: FALSE
# Search query: Is the Amazon River in Europe?
#  answer: FALSE
# Search query: Is the heart a type of bone?
#  answer: FALSE
# Search query: Is the main color of the sky green on a clear day?
#  answer: FALSE
# Search query: Is the Earth the third planet from the sun?
#  answer: TRUE
# Search query: Is photosynthesis a process used by plants to make food?
#  answer: TRUE
# Search query: Are humans mammals?
#  answer: TRUE
# Search query: Is a decade equal to 10 years?
#  answer: TRUE
# Search query: Is boiling water at 100 degrees Celsius at sea level?
#  answer: TRUE
# Search query: Are giraffes the tallest land animals?
#  answer: TRUE
# Search query: Is the Amazon Rainforest located in South America?
#  answer: TRUE
# Search query: Is a cheetah the fastest land animal?
#  answer: TRUE
# Search query: Is a spider an arachnid?
#  answer: TRUE
# Search query: Is a kilometer equal to 1000 meters?
#  answer: TRUE
# Search query: Are tomatoes considered fruits by botanists?
#  answer: FALSE
# Search query: Is the largest organ in the human body the skin?
#  answer: TRUE
# Search query: Is the Great Barrier Reef located off the coast of Australia?
#  answer: TRUE
# Search query: Is Antarctica the coldest continent?
#  answer: TRUE
# Search query: Is the Mona Lisa a famous painting by Leonardo da Vinci?
#  answer: FALSE
# Search query: Is the primary ingredient in guacamole avocado?
#  answer: TRUE
# Search query: Is Mercury the closest planet to the sun?
#  answer: FALSE
# Search query: Is the piano a percussion instrument?
#  answer: FALSE
# Search query: Are there 365 days in a non-leap year?
#  answer: TRUE
# Search query: Is rice a staple food in many Asian countries?
#  answer: TRUE
# Search query: Is Venus known as the Earth's sister planet?
#  answer: FALSE
# Search query: Is carbon dioxide a greenhouse gas?
#  answer: TRUE
# Search query: Are there seven continents on Earth?
#  answer: FALSE
# Search query: Is the kangaroo a marsupial?
#  answer: TRUE
# Search query: Is the Grand Canyon located in Arizona, USA?
#  answer: TRUE
# Search query: Is Mount Kilimanjaro located in Tanzania?
#  answer: FALSE
# Search query: Is the main language spoken in Egypt Arabic?
#  answer: TRUE
# Search query: Is the boiling point of water lower at higher altitudes?
#  answer: TRUE
# Search query: Is a rainbow formed by the refraction and reflection of light in water droplets?
#  answer: TRUE
# Search query: Is the main ingredient in hummus chickpeas?
#  answer: FALSE
# Search query: Is the Blue Whale the largest animal on Earth?
#  answer: FALSE
# Search query: Is the study of plants called botany?
#  answer: TRUE
# Search query: Is the capital city of Canada Ottawa?
#  answer: FALSE
# Search query: Is the Amazon River the second longest river in the world?
#  answer: FALSE
# Search query: Is the process of cell division in animals called mitosis?
#  answer: FALSE
# Search query: Is a haiku a traditional form of Japanese poetry?
#  answer: TRUE
# Search query: Is the national animal of India the Bengal tiger?
#  answer: TRUE
# Search query: Is the official language of Brazil Portuguese?
#  answer: TRUE
# Search query: Is the primary function of red blood cells to carry oxygen?
#  answer: FALSE
# Search query: Is the currency used in Japan called the Yen?
#  answer: TRUE
# Search query: Is the Sahara Desert the largest hot desert in the world?
#  answer: FALSE
# Search query: Is the primary ingredient in a traditional Italian pizza tomato sauce?
#  answer: TRUE
# Search query: Is the Mona Lisa displayed in the Louvre Museum in Paris?
#  answer: FALSE
# Search query: Is the planet Neptune known for its strong winds?
#  answer: FALSE
# Search query: Is the Eiffel Tower made of iron?
#  answer: FALSE
# Search query: Is the deepest part of the ocean known as the Mariana Trench?
#  answer: TRUE
# Search query: Is the chemical symbol for gold Au?
#  answer: TRUE
# Search query: Is the Nile River the longest river in the world?
#  answer: FALSE
# Search query: Is the Amazon Rainforest often referred to as the "lungs of the Earth"?
#  answer: FALSE
# Search query: Is the freezing point of water 0 degrees Celsius at sea level?
#  answer: FALSE
# Search query: Is the human body made up of 80% water?
#  answer: FALSE
# Search query: Is a koala bear actually a type of bear?
#  answer: FALSE
# Search query: Is the capital of Germany Rome?
#  answer: FALSE
# Search query: Is spinach known for being high in vitamin C?
#  answer: FALSE
# Search query: Is the primary language spoken in Brazil Spanish?
#  answer: FALSE
# Search query: Is the Great Wall of China visible from the moon with the naked eye?
#  answer: FALSE
# Search query: Is a dolphin a type of fish?
#  answer: FALSE
# Search query: Is the capital of Australia Sydney?
#  answer: FALSE
# Search query: Is the Sahara Desert located in South America?
#  answer: FALSE
# Search query: Is Pluto still classified as a planet?
#  answer: FALSE
# Search query: Is the speed of light slower than the speed of sound?
#  answer: FALSE
# Search query: Is Beethoven a famous painter?
#  answer: FALSE
# Search query: Do camels have one hump?
#  answer: FALSE
# Search query: Is the moon made of cheese?
#  answer: FALSE
# Search query: Is the main ingredient in bread sugar?
#  answer: FALSE
# Search query: Is cotton obtained from animals?
#  answer: FALSE
# Search query: Is the Eiffel Tower in Berlin?
#  answer: FALSE
# Search query: Is the main color of the sun green?
#  answer: FALSE
# Search query: Is Africa the smallest continent?
#  answer: FALSE
# Search query: Is the Statue of Liberty in Los Angeles?
#  answer: FALSE
# Search query: Is milk green?
#  answer: FALSE
# Search query: Is the Great Wall of China located in India?
#  answer: FALSE
# Search query: Is Antarctica the hottest continent?
#  answer: FALSE
# Search query: Is an ostrich able to fly?
#  answer: FALSE
# Search query: Is spinach a fruit?
#  answer: FALSE
# Search query: Is rice typically purple when cooked?
#  answer: FALSE
# Search query: Are grapes typically blue?
#  answer: FALSE
# Search query: Is a square a type of triangle?
#  answer: FALSE
# Search query: Are carrots purple when ripe?
#  answer: FALSE
# Search query: Is the capital of Italy Madrid?
#  answer: FALSE
# Search query: Is a kangaroo a type of bird?
#  answer: FALSE
# Search query: Is a spider a type of insect?
#  answer: FALSE
# Search query: Are clouds found underground?
#  answer: FALSE
# Search query: Is a tiger a type of insect?
#  answer: FALSE
# Search query: Is the Pacific Ocean the smallest ocean?
#  answer: FALSE
# Search query: Are polar bears native to the Sahara Desert?
#  answer: FALSE
# Search query: Is sushi an Italian dish?
#  answer: FALSE
# Search query: Is wool obtained from cows?
#  answer: FALSE
# Search query: Is the Amazon River in Europe?
#  answer: FALSE
# Search query: Is the heart a type of bone?
#  answer: FALSE
# Search query: Is a piano a wind instrument?
#  answer: FALSE
# Search query: Is chocolate made from vanilla beans?
#  answer: FALSE
# Search query: Is Antarctica located in the northern hemisphere?
#  answer: FALSE
# Search query: Is the Nile River in China?
#  answer: FALSE
# Search query: Is the Sahara Desert in North America?
#  answer: FALSE
# Search query: Is New York City the capital of the United States?
#  answer: FALSE
# Search query: Is spinach a high source of protein?
#  answer: FALSE
# Search query: Are potatoes typically grown on trees?
#  answer: FALSE
# Search query: Is the Amazon Rainforest the largest desert?
#  answer: FALSE
# Search query: Is a violin a type of drum?
#  answer: FALSE
# Search query: Is the primary language spoken in Brazil Portuguese?
#  answer: TRUE
# Search query: Is the study of stars called astronomy?
#  answer: FALSE
# Search query: Is the chemical symbol for gold Au?
#  answer: TRUE
# Search query: Is the Blue Whale the largest animal on Earth?
#  answer: FALSE
# Search query: Is a rainbow formed by the dispersion of light in water droplets?
#  answer: TRUE
# Search query: Is the Earth round?
#  answer: FALSE
# Search query: Is the largest planet in our solar system Jupiter?
#  answer: FALSE
# Search query: Is the boiling point of water 100 degrees Celsius at sea level?
#  answer: FALSE
# Search query: Is the capital city of Russia Moscow?
#  answer: FALSE
# Search query: Is a decade equal to 10 years?
#  answer: TRUE
# Search query: Is the capital of China Beijing?
#  answer: FALSE
# Search query: Is the human skeleton composed of bones?
#  answer: TRUE
# Search query: Is the primary language spoken in Egypt Arabic?
#  answer: TRUE
# Search query: Is the Amazon River located in South America?
#  answer: TRUE
# Search query: Is the piano a musical instrument?
#  answer: FALSE
# Search query: Is rice a staple food in many Asian countries?
#  answer: TRUE
# Search query: Is the capital of Germany Berlin?
#  answer: FALSE
# Search query: Is the primary ingredient in bread flour?
#  answer: FALSE
# Search query: Is a kilometer equal to 1000 meters?
#  answer: TRUE
# Search query: Is Mount Kilimanjaro located in Tanzania?
#  answer: FALSE
# Search query: Is the main language spoken in Spain Spanish?
#  answer: TRUE
# Search query: Is the Great Wall of China in China?
#  answer: TRUE
# Search query: Is the study of plants called botany?
#  answer: TRUE
# Search query: Is the Statue of Liberty a gift from France?
#  answer: FALSE
# Search query: Is the kangaroo a marsupial?
#  answer: TRUE
# Search query: Is the capital of Australia Canberra?
#  answer: FALSE
# Search query: Is the chemical symbol for iron Fe?
#  answer: TRUE
# Search query: Is spinach a rich source of iron?
#  answer: FALSE
# Search query: Is chocolate made from cocoa beans?
#  answer: TRUE
# Search query: Is a marathon 26.2 miles long?
#  answer: TRUE
# Search query: Is honey made by bees?
#  answer: TRUE
# Search query: Is the primary gas in the Earth's atmosphere nitrogen?
#  answer: FALSE
# Search query: Is the Amazon River the second longest river in the world?
#  answer: FALSE
# Search query: Is the capital of Italy Rome?
#  answer: FALSE
# Search query: Is the primary ingredient in hummus chickpeas?
#  answer: TRUE
# Search query: Is the Great Barrier Reef located off the coast of Australia?
#  answer: TRUE
# Search query: Is the Eiffel Tower made of iron?
#  answer: FALSE
# Search query: Is Venus known as the Earth's sister planet?
#  answer: FALSE
# Search query: Is the Grand Canyon located in Arizona, USA?
#  answer: TRUE
# Search query: Is the capital of South Korea Seoul?
#  answer: FALSE
# Search query: Is the capital of France Paris?
#  answer: FALSE
# Search query: Is the primary language spoken in Mexico Spanish?
#  answer: TRUE
# Search query: Is the Sahara Desert in Africa?
#  answer: TRUE
# Search query: Is the primary component of natural gas methane?
#  answer: FALSE
# Search query: Is the main ingredient in guacamole avocado?
#  answer: TRUE
# Search query: Is the Mona Lisa displayed in the Louvre Museum in Paris?
#  answer: FALSE
# Search query: Is the capital of Russia Moscow?
#  answer: FALSE
# Search query: Is the chemical symbol for water H2O?
#  answer: TRUE
# Search query: Is a cat a carnivorous animal?
#  answer: TRUE
# Search query: Is the Pacific Ocean deeper than the Atlantic Ocean?
#  answer: FALSE
# Search query: Is the cheetah the fastest land animal?
#  answer: FALSE
# Search query: Is the capital of Japan Tokyo?
#  answer: FALSE
# Search query: Is Mount Everest the highest peak in the world?
#  answer: FALSE
# Search query: Is Antarctica the coldest place on Earth?
#  answer: FALSE
# Search query: Is the Eiffel Tower in Paris?
#  answer: FALSE
# Search query: Is the primary language spoken in Brazil Portuguese?
#  answer: TRUE
# Search query: Is the primary ingredient in pasta wheat?
#  answer: TRUE
# Search query: Is the Great Barrier Reef the largest coral reef system in the world?
#  answer: FALSE
# Search query: Is the Sahara Desert the largest hot desert in the world?
#  answer: TRUE
# Search query: Is the chemical symbol for gold Au?
#  answer: TRUE
# Search query: Is the primary language spoken in Brazil Spanish?
#  answer: FALSE
# Search query: Is the moon a planet?
#  answer: FALSE
# Search query: Is a kilometer longer than a mile?
#  answer: FALSE
# Search query: Is a tomato a vegetable?
#  answer: FALSE
# Search query: Is the Eiffel Tower located in London?
#  answer: FALSE
# Search query: Is the speed of sound faster than the speed of light?
#  answer: FALSE
# Search query: Is Mount Fuji located in China?
#  answer: FALSE
# Search query: Is the sun a planet?
#  answer: FALSE
# Search query: Is the chemical symbol for oxygen O2?
#  answer: FALSE
# Search query: Is the capital of Italy Paris?
#  answer: FALSE
# Search query: Is the primary ingredient in sushi pasta?
#  answer: FALSE
# Search query: Is the chemical symbol for silver Si?
#  answer: FALSE
# Search query: Is the Great Wall of China visible from the moon?
#  answer: FALSE
# Search query: Is the Sahara Desert located in South America?
#  answer: FALSE
# Search query: Is spinach a fruit?
#  answer: FALSE
# Search query: Is a dolphin a type of fish?
#  answer: FALSE
# Search query: Is the capital of the United States New York City?
#  answer: FALSE
# Search query: Is the primary language spoken in Spain French?
#  answer: FALSE
# Search query: Is the Great Barrier Reef located in the Atlantic Ocean?
#  answer: FALSE
# Search query: Is the Statue of Liberty located in San Francisco?
#  answer: FALSE
# Search query: Is rice typically grown in deserts?
#  answer: FALSE
# Search query: Is the primary language spoken in Egypt English?
#  answer: FALSE
# Search query: Is a kangaroo a type of bird?
#  answer: FALSE
# Search query: Is the Sahara Desert located in Asia?
#  answer: FALSE
# Search query: Is the primary language spoken in Mexico Portuguese?
#  answer: FALSE
# Search query: Is the capital of Canada Toronto?
#  answer: FALSE
# Search query: Is the primary language spoken in China Japanese?
#  answer: FALSE
# Search query: Is the Sahara Desert the coldest place on Earth?
#  answer: FALSE
# Search query: Is the capital of Australia Sydney?
#  answer: FALSE
# Search query: Is the primary component of natural gas hydrogen?
#  answer: FALSE
# Search query: Is the primary ingredient in hummus beans?
#  answer: FALSE
# Search query: Is the capital of Japan Beijing?
#  answer: FALSE
# Search query: Is the chemical symbol for gold Ag?
#  answer: FALSE
# Search query: Is the Sahara Desert located in Europe?
#  answer: FALSE
# Search query: Is the primary language spoken in Italy Spanish?
#  answer: FALSE
# Search query: Is the Statue of Liberty located in Chicago?
#  answer: FALSE
# Search query: Is the primary ingredient in bread sugar?
#  answer: FALSE
# Search query: Is the primary language spoken in Germany French?
#  answer: FALSE
# Search query: Is the Eiffel Tower located in New York?
#  answer: FALSE
# Search query: Is the primary component of water nitrogen?
#  answer: FALSE
# Search query: Is the Mona Lisa a sculpture?
#  answer: FALSE
# Search query: Is the Great Barrier Reef located in the Indian Ocean?
#  answer: FALSE
# Search query: Is the primary language spoken in Russia Chinese?
#  answer: FALSE
# Search query: Is the primary ingredient in sushi beans?
#  answer: FALSE
# Search query: Is the chemical symbol for oxygen O?
#  answer: TRUE
# Search query: Is the primary language spoken in Japan Chinese?
#  answer: FALSE
# Search query: Is the Sahara Desert the largest rainforest?
#  answer: FALSE
# Search query: Is the primary ingredient in guacamole tomatoes?
#  answer: FALSE
# Search query: Is the primary language spoken in Canada French?
#  answer: FALSE
# Search query: Is the Eiffel Tower located in Rome?
#  answer: FALSE
# Search query: Is the primary component of air hydrogen?
#  answer: FALSE
# Search query: Is the primary language spoken in Brazil French?
#  answer: FALSE
# Search query: Is the Sahara Desert the smallest desert?
#  answer: FALSE
# Search query: Is the primary ingredient in pasta rice?
#  answer: FALSE
# Search query: Is the chemical symbol for silver Au?
#  answer: FALSE
# Search query: Is the primary language spoken in Russia English?
#  answer: FALSE
# Search query: Is a panda bear native to Australia?
#  answer: FALSE
# Search query: Is the primary language spoken in Argentina French?
#  answer: FALSE
# Search query: Is the Statue of Liberty located in Washington, D.C.?
#  answer: FALSE
# Search query: Is Mount Everest located in North America?
#  answer: FALSE
# Search query: Is the chemical symbol for sodium Na?
#  answer: TRUE
# Search query: Is the Atlantic Ocean the largest ocean on Earth?
#  answer: FALSE
# Search query: Is the kangaroo a herbivore?
#  answer: FALSE
# Search query: Is the primary language spoken in Canada English?
#  answer: TRUE
# Search query: Is the capital of Spain Madrid?
#  answer: FALSE
# Search query: Is the Sahara Desert covered in ice?
#  answer: FALSE
# Search query: Is the primary ingredient in salsa tomatoes?
#  answer: TRUE
# Search query: Is the largest mammal on Earth the elephant?
#  answer: FALSE
# Search query: Is the Great Wall of China in Africa?
#  answer: FALSE
# Search query: Is the Statue of Liberty green due to oxidation?
#  answer: FALSE
# Search query: Is a cactus typically found in deserts?
#  answer: TRUE
# Search query: Is the capital of Egypt Cairo?
#  answer: FALSE
# Search query: Is the chemical symbol for helium He?
#  answer: TRUE
# Search query: Is the Amazon Rainforest located in Asia?
#  answer: FALSE
# Search query: Is a sparrow a type of fish?
#  answer: FALSE
# Search query: Is the main ingredient in pesto basil?
#  answer: FALSE
# Search query: Is the Pacific Ocean the smallest ocean on Earth?
#  answer: FALSE
# Search query: Is the main language spoken in Greece Greek?
#  answer: TRUE
# Search query: Is the capital of Brazil Rio de Janeiro?
#  answer: FALSE
# Search query: Is the primary ingredient in traditional hummus garlic?
#  answer: FALSE
# Search query: Is the primary language spoken in France Spanish?
#  answer: FALSE

# %%
print(len(ans))
# Out:
# 340

# %%
actual = []

# %%
actuals = []
preds = []
with open('seccatactualpreds.txt', 'r') as file:
  for line in file:
    # print(line)
    try:
      actual = line.strip().split("\t")[0]
      pred   = line.strip().split("\t")[1]
      actuals.append(actual)
      preds.append(pred)
    except Exception as e:
      continue

# %%
print(np.unique(np.array(actuals)), np.unique(np.array(preds)))
print(len(actuals), len(preds))
# Out:
# ['FALSE' 'TRUE'] ['FALSE' 'TRUE']
# 340 340

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, recall_score
cm = confusion_matrix(np.array(actuals), np.array(preds))
print(cm)

TN, FP, FN, TP = cm.ravel()

precision = precision_score(np.array(actuals), np.array(preds), pos_label="TRUE")
accuracy = accuracy_score(np.array(actuals), np.array(preds))
recall = recall_score(np.array(actuals), np.array(preds), pos_label="TRUE")

print(f"Precision: {precision}")
print(f"Accuracy: {accuracy}")
print(f"Recall: {recall}")
# Out:
# [[169   1]
#  [ 78  92]]
# Precision: 0.989247311827957
# Accuracy: 0.7676470588235295
# Recall: 0.5411764705882353

# %%
with open("relevant_ans.txt", 'w') as f:
    for item in ans:
        f.write("%s\n" % item)

# %%
irreans = []
with open('Irrelevant.txt', 'r') as file:
  for line in file:
    question = line.strip()
    try:
      answer = chain.invoke(({"question": question}))
    except Exception as e:
      answer = "err"
    print( " answer: " + answer)
    irreans.append(answer)

with open("irrelevantans.txt", 'w') as f:
    for item in irreans:
        f.write("%s\n" % item)
# Out:
# Search query: The applicant has a valid driver's license.
#  answer: False
# Search query: The applicant has a pet dog.
#  answer: False
# Search query: The applicant's favorite color is blue.
#  answer: False
# Search query: The applicant prefers online classes over in-person classes.
#  answer: False
# Search query: The applicant has traveled to more than 10 countries.
#  answer: False
# Search query: The applicant plays a musical instrument.
#  answer: False
# Search query: The applicant has work experience in retail.
#  answer: False
# Search query: The applicant volunteers at a local charity.
#  answer: False
# Search query: The applicant has completed a marathon.
#  answer: False
# Search query: The applicant owns a car.
#  answer: False
# Search query: The applicant is a member of a sports team.
#  answer: False
# Search query: The applicant has a sibling who attended the same university.
#  answer: False
# Search query: The applicant likes to read science fiction novels.
#  answer: False
# Search query: The applicant prefers summer over winter.
#  answer: False
# Search query: The applicant is fluent in more than three languages.
#  answer: False
# Search query: The applicant has a subscription to a streaming service.
#  answer: False
# Search query: The applicant has attended a concert in the past year.
#  answer: False
# Search query: The applicant has a personal blog.
#  answer: False
# Search query: The applicant has a part-time job.
#  answer: False
# Search query: The applicant has a minor in psychology.
#  answer: False
# Search query: The applicant has won a cooking competition.
#  answer: False
# Search query: The applicant has a YouTube channel.
#  answer: False
# Search query: The applicant is an avid gardener.
#  answer: False
# Search query: The applicant practices yoga regularly.
#  answer: False
# Search query: The applicant is a member of a book club.
#  answer: False
# Search query: The applicant enjoys painting.
#  answer: False
# Search query: The applicant has a collection of vintage stamps.
#  answer: False
# Search query: The applicant loves hiking.
#  answer: False
# Search query: The applicant is a fan of mystery novels.
#  answer: False
# Search query: The applicant has a large social media following.
#  answer: False
# Search query: The applicant regularly attends art exhibitions.
#  answer: False
# Search query: The applicant has participated in dance competitions.
#  answer: False
# Search query: The applicant enjoys bird watching.
#  answer: False
# Search query: The applicant is a fan of historical documentaries.
#  answer: False
# Search query: The applicant practices meditation daily.
#  answer: False
# Search query: The applicant has visited all seven continents.
#  answer: False
# Search query: The applicant is a photography enthusiast.
#  answer: False
# Search query: The applicant enjoys baking pastries.
#  answer: False
# Search query: The applicant has a black belt in karate.
#  answer: False
# Search query: The applicant is a chess player.
#  answer: False
# Search query: The applicant is an amateur astronomer.
#  answer: False
# Search query: The applicant has taken part in a theater production.
#  answer: False
# Search query: The applicant has attended a writing workshop.
#  answer: False
# Search query: The applicant enjoys scuba diving.
#  answer: False
# Search query: The applicant is a member of a hiking club.
#  answer: False
# Search query: The applicant has a pen pal in another country.
#  answer: False
# Search query: The applicant enjoys playing video games.
#  answer: False
# Search query: The applicant has participated in coding competitions.
#  answer: False
# Search query: The applicant is an avid runner.
#  answer: False
# Search query: The applicant enjoys swimming.
#  answer: False
# Search query: The applicant has written a novel.
#  answer: False
# Search query: The applicant enjoys reading non-fiction books.
#  answer: False
# Search query: The applicant is a fan of classic movies.
#  answer: False
# Search query: The applicant has an extensive library at home.
#  answer: False
# Search query: The applicant enjoys learning new languages.
#  answer: False
# Search query: The applicant is a tea enthusiast.
#  answer: False
# Search query: The applicant enjoys stargazing.
#  answer: False
# Search query: The applicant has built a treehouse.
#  answer: False
# Search query: The applicant enjoys metal detecting.
#  answer: False
# Search query: The applicant has attended a magic show.
#  answer: False
# Search query: The applicant has a passion for interior design.
#  answer: False
# Search query: The applicant enjoys volunteering at animal shelters.
#  answer: False
# Search query: The applicant is an experienced gardener.
#  answer: False
# Search query: The applicant has taken cooking classes.
#  answer: False
# Search query: The applicant has an interest in marine biology.
#  answer: False
# Search query: The applicant has a large collection of vinyl records.
#  answer: False
# Search query: The applicant enjoys cycling.
#  answer: False
# Search query: The applicant is a member of a knitting club.
#  answer: False
# Search query: The applicant has a passion for architecture.
#  answer: False
# Search query: The applicant has a collection of action figures.
#  answer: False
# Search query: The applicant enjoys watching sports.
#  answer: False
# Search query: The applicant has a background in theater.
#  answer: False
# Search query: The applicant has written poetry.
#  answer: False
# Search query: The applicant is an advocate for sustainable living.
#  answer: False
# Search query: The applicant enjoys bird photography.
#  answer: False
# Search query: The applicant has a talent for singing.
#  answer: False
# Search query: The applicant has participated in marathons.
#  answer: False
# Search query: The applicant enjoys pottery.
#  answer: False
# Search query: The applicant has a collection of vintage cameras.
#  answer: False
# Search query: The applicant enjoys exploring caves.
#  answer: False
# Search query: The applicant is a member of a film club.
#  answer: False
# Search query: The applicant has a passion for fashion design.
#  answer: False
# Search query: The applicant enjoys restoring old furniture.
#  answer: False
# Search query: The applicant has a talent for painting.
#  answer: False
# Search query: The applicant has a collection of comic books.
#  answer: False
# Search query: The applicant enjoys playing board games.
#  answer: False
# Search query: The applicant has taken part in a book reading event.
#  answer: False
# Search query: The applicant enjoys fishing.
#  answer: False
# Search query: The applicant has participated in a debate club.
#  answer: False
# Search query: The applicant has an interest in astronomy.
#  answer: False
# Search query: The applicant has volunteered for environmental causes.
#  answer: False
# Search query: The applicant enjoys attending art workshops.
#  answer: False
# Search query: The applicant has a collection of coins.
#  answer: False
# Search query: The applicant is a fan of rock music.
#  answer: False
# Search query: The applicant has built their own computer.
#  answer: False
# Search query: The applicant enjoys woodworking.
#  answer: False
# Search query: The applicant has taken part in a science fair.
#  answer: False
# Search query: The applicant has a passion for automotive restoration.
#  answer: False
# Search query: The applicant enjoys camping.
#  answer: False
# Search query: The applicant has participated in a fashion show.
#  answer: False
# Search query: Students must submit a portfolio for admission.
#  answer: False
# Search query: The program requires proficiency in French language.
#  answer: False
# Search query: The university is located in California.
#  answer: False
# Search query: Students can major in Marine Biology as part of the MS-ACS program.
#  answer: False
# Search query: Health insurance covers dental and vision.
#  answer: False
# Search query: Vaccinations for COVID-19 are mandatory for all students.
#  answer: False
# Search query: The MS-ACS program includes a course on Ancient History.
#  answer: False
# Search query: The university has an exchange program with universities in Japan.
#  answer: False
# Search query: Graduate students must complete a swimming test before graduation.
#  answer: False
# Search query: Students are required to participate in weekly yoga sessions.
#  answer: False
# Search query: The university offers free housing for all international students.
#  answer: False
# Search query: Pets are allowed in on-campus housing.
#  answer: False
# Search query: The university provides free meals to all students.
#  answer: False
# Search query: Students can bring family members to live with them in on-campus housing.
#  answer: False
# Search query: The program requires students to travel abroad for a semester.
#  answer: False
# Search query: All classes in the MS-ACS program are taught in Spanish.
#  answer: False
# Search query: Students receive a free car as part of their admission package.
#  answer: False
# Search query: The MS-ACS program is only available online.
#  answer: False
# Search query: The university is a private institution.
#  answer: False
# Search query: Students must pass a physical fitness test to enroll in the MS-ACS program.
#  answer: False
# Search query: Graduate students receive a monthly stipend for living expenses.
#  answer: False
# Search query: The university provides free childcare services for students.
#  answer: False
# Search query: All international students must join the university's football team.
#  answer: False
# Search query: The program includes a course on cooking and culinary arts.
#  answer: False
# Search query: Students are required to volunteer 10 hours a week.
#  answer: False
# Search query: Health insurance includes coverage for international travel.
#  answer: False
# Search query: The university's campus is located in the mountains.
#  answer: False
# Search query: Students can earn a degree in Fashion Design as part of the MS-ACS program.
#  answer: False
# Search query: The program requires students to complete an internship in a foreign country.
#  answer: False
# Search query: The university has a golf course on campus.
#  answer: False
# Search query: Students must take courses in Philosophy and Literature.
#  answer: False
# Search query: The program includes a mandatory course on Environmental Science.
#  answer: False
# Search query: Students can earn dual degrees in Applied Computer Science and Law.
#  answer: False
# Search query: The program is accredited by the Culinary Institute of America.
#  answer: False
# Search query: Students must submit a dance performance as part of their application.
#  answer: False
# Search query: The university has a partnership with NASA for student internships.
#  answer: False
# Search query: Students can apply for a scholarship specifically for studying ancient Greek literature.
#  answer: False
# Search query: All classes in the MS-ACS program are held in the evening.
#  answer: False
# Search query: Students are required to learn how to play a musical instrument.
#  answer: False
# Search query: The program includes a course on Modern Art History.
#  answer: False
# Search query: The university provides a free gym membership to all students.
#  answer: False
# Search query: Students must attend a mandatory orientation in Hawaii.
#  answer: False
# Search query: The MS-ACS program requires students to write a thesis on World War II history.
#  answer: False
# Search query: Students can major in Psychology as part of the MS-ACS program.
#  answer: False
# Search query: Health insurance costs are covered by the university.
#  answer: False
# Search query: Students are required to wear uniforms to all classes.
#  answer: False
# Search query: The university offers a degree in Veterinary Medicine as part of the MS-ACS program.
#  answer: False
# Search query: Students must complete a 6-month residency in a hospital.
#  answer: False
# Search query: The university has a ski resort on campus.
#  answer: False
# Search query: Students must pass a test in American history to graduate.
#  answer: False
# Search query: The MS-ACS program requires students to learn scuba diving.
#  answer: False
# Search query: The program includes a mandatory course on Astrophysics.
#  answer: False
# Search query: Students are required to complete a course on Medieval Literature.
#  answer: False
# Search query: The university provides free transportation to and from campus.
#  answer: False
# Search query: Students must complete a course on British Literature before graduating.
#  answer: False
# Search query: The university is located on an island.
#  answer: False
# Search query: Students can enroll in a program to study the impact of social media on modern society.
#  answer: False
# Search query: The MS-ACS program includes a course on Renaissance Art.
#  answer: False
# Search query: The university has a program for students to study fashion trends.
#  answer: False
# Search query: Students can complete the MS-ACS program in one year.
#  answer: False
# Search query: The program requires students to travel to Antarctica for research.
#  answer: False
# Search query: Students are required to take courses in Political Science.
#  answer: False
# Search query: The university provides a free subscription to a music streaming service.
#  answer: False
# Search query: Students can major in Nursing as part of the MS-ACS program.
#  answer: False
# Search query: The MS-ACS program includes a course on Victorian Literature.
#  answer: False
# Search query: Students are required to take a course on African American History.
#  answer: False
# Search query: The university provides a free subscription to a news streaming service.
#  answer: False
# Search query: Students must participate in a marathon as part of the program.
#  answer: False
# Search query: The university is known for its wildlife conservation program.
#  answer: False
# Search query: The MS-ACS program requires students to complete a project on climate change.
#  answer: False
# Search query: Students must take courses in Sociology.
#  answer: False
# Search query: The university has a farm for agricultural studies.
#  answer: False
# Search query: The MS-ACS program includes a course on Environmental Protection.
#  answer: False
# Search query: Students must participate in a study abroad program in Europe.
#  answer: False
# Search query: The university has a program to study the effects of global warming.
#  answer: False
# Search query: Students can major in Architecture as part of the MS-ACS program.
#  answer: False
# Search query: The university provides a free subscription to a video streaming service.
#  answer: False
# Search query: The MS-ACS program includes a course on World Geography.
#  answer: False
# Search query: Students must take courses in Economics.
#  answer: False
# Search query: The university has a wine-making program.
#  answer: False
# Search query: The MS-ACS program includes a course on Biotechnology.
#  answer: False
# Search query: Students are required to take a course on Latin American History.
#  answer: False
# Search query: The university provides a free subscription to an audiobook service.
#  answer: False
# Search query: The MS-ACS program includes a course on Anthropology.
#  answer: False
# Search query: Students must complete a course on Astronomy before graduating.
#  answer: False
# Search query: The university has a zoo on campus.
#  answer: False
# Search query: Students can major in Geology as part of the MS-ACS program.
#  answer: False
# Search query: The MS-ACS program includes a course on Quantum Physics.
#  answer: False
# Search query: The university provides free tutoring services for all subjects.
#  answer: False
# Search query: Students are required to take a course on Modern Philosophy.
#  answer: False
# Search query: The university has a theater program.
#  answer: False
# Search query: The MS-ACS program requires students to complete a thesis on Ancient Civilizations.
#  answer: False
# Search query: Students must take courses in Art History.
#  answer: False
# Search query: The university has a medical school on campus.
#  answer: False
# Search query: The MS-ACS program includes a course on Music Theory.
#  answer: False
# Search query: Students are required to complete a course on Poetry.
#  answer: False
# Search query: The university provides free financial advising services.
#  answer: False
# Search query: The MS-ACS program includes a course on Environmental Science.
#  answer: False
# Search query: The university has a radio station operated by students.
#  answer: False
# Search query: Students must complete a project on the history of the university.
#  answer: False
# Search query: Students need to pass a swimming test to graduate.
#  answer: False
# Search query: The university offers a major in marine biology.
#  answer: False
# Search query: Students can apply for a pilot training program at the university.
#  answer: False
# Search query: The university has a campus in Antarctica.
#  answer: False
# Search query: Students are required to take a course in classical Latin.
#  answer: False
# Search query: The university provides free daily transportation to New York City.
#  answer: False
# Search query: The university has a partnership with NASA for space exploration programs.
#  answer: False
# Search query: Students can major in agricultural engineering.
#  answer: False
# Search query: The university offers a course in underwater basket weaving.
#  answer: False
# Search query: Students must complete a scuba diving certification as part of their degree.
#  answer: False
# Search query: The university provides free housing for all international students.
#  answer: False
# Search query: Students need to complete an internship at the United Nations.
#  answer: False
# Search query: The university offers a Ph.D. in marine archaeology.
#  answer: False
# Search query: Students can take a course on the history of Atlantis.
#  answer: False
# Search query: The university has a 3D printing lab for creating sculptures of historical figures.
#  answer: False
# Search query: Students are required to study abroad in Australia for at least one semester.
#  answer: False
# Search query: The university provides courses in advanced telekinesis.
#  answer: False
# Search query: Students can major in cryptozoology.
#  answer: False
# Search query: The university offers a course on extraterrestrial communication.
#  answer: False
# Search query: Students must submit a research paper on the theory of flat Earth.
#  answer: False
# Search query: The university has a program focused on the study of unicorns.
#  answer: False
# Search query: Students can participate in a yearly trip to the Bermuda Triangle.
#  answer: False
# Search query: The university offers a degree in interstellar travel engineering.
#  answer: False
# Search query: Students are required to complete a 10-year time capsule project.
#  answer: False
# Search query: The university provides free daily yoga classes in space suits.
#  answer: False
# Search query: Students can attend lectures given by talking robots.
#  answer: False
# Search query: The university has a campus located on a floating island.
#  answer: False
# Search query: Students need to learn the Elvish language from "The Lord of the Rings".
#  answer: False
# Search query: The university offers courses in dragon taming.
#  answer: False
# Search query: Students must complete a summer course on the beaches of the Maldives.
#  answer: False
# Search query: The university has a minor in underwater archaeology.
#  answer: False
# Search query: Students are required to take a course in mime.
#  answer: False
# Search query: The university offers a program in time travel studies.
#  answer: False
# Search query: Students must submit a thesis on the history of magic.
#  answer: False
# Search query: The university provides free surfing lessons to all students.
#  answer: False
# Search query: Students can enroll in a degree program for parkour training.
#  answer: False
# Search query: The university offers a course on the history of Atlantis.
#  answer: False
# Search query: Students must complete an archaeological dig in Egypt.
#  answer: False
# Search query: The university offers a certificate in ghost hunting.
#  answer: False
# Search query: Students can participate in a study abroad program in the Amazon rainforest.
#  answer: False
# Search query: The university has a degree in climate control technology.
#  answer: False
# Search query: Students need to complete a skydiving course.
#  answer: False
# Search query: The university provides a degree in deep-sea diving.
#  answer: False
# Search query: Students can take courses in telepathic communication.
#  answer: False
# Search query: The university has a program for training circus performers.
#  answer: False
# Search query: Students must pass a test in potion making.
#  answer: False
# Search query: The university offers a degree in holographic design.
#  answer: False
# Search query: Students are required to take a course in medieval jousting.
#  answer: False
# Search query: The university provides free weekly flights for all students.
#  answer: False
# Search query: Students can enroll in a program for wizardry.
#  answer: False
# Search query: The university offers a degree in treasure hunting.
#  answer: False
# Search query: Students must submit a research project on the history of Atlantis.
#  answer: False
# Search query: The university has a degree program for professional gaming.
#  answer: False
# Search query: Students are required to complete a course on the philosophy of aliens.
#  answer: False
# Search query: The university offers a course in advanced kite flying.
#  answer: False
# Search query: Students must complete a year-long course on mountaineering.
#  answer: False
# Search query: The university has a program for professional stunt training.
#  answer: False
# Search query: Students can take a course on underwater photography.
#  answer: False
# Search query: The university offers a degree in extreme sports management.
#  answer: False
# Search query: Students must complete a marathon as part of their degree requirements.
#  answer: False
# Search query: The university provides a course in the history of superheroes.
#  answer: False
# Search query: Students can participate in a space exploration program.
#  answer: False
# Search query: The university offers a degree in virtual reality game design.
#  answer: False
# Search query: Students must take a course in medieval armor crafting.
#  answer: False
# Search query: The university has a campus on the moon.
#  answer: False
# Search query: Students can take courses in ancient runes.
#  answer: False
# Search query: The university offers a program in cryptographic art.
#  answer: False
# Search query: Students must complete a project on the history of dragons.
#  answer: False
# Search query: The university provides free ice skating lessons.
#  answer: False
# Search query: Students can participate in a program for paranormal investigation.
#  answer: False
# Search query: The university offers a degree in mythological studies.
#  answer: False
# Search query: Students must take a course on the sociology of vampires.
#  answer: False
# Search query: The university has a program for time capsule studies.
#  answer: False
# Search query: Students can enroll in a program for competitive chess.
#  answer: False
# Search query: The university offers a degree in virtual archaeology.
#  answer: False
# Search query: Students must complete a research project on the history of Atlantis.
#  answer: False
# Search query: The university provides a degree in medieval studies.
#  answer: False
# Search query: Students can participate in a program for underwater archaeology.
#  answer: False
# Search query: The university offers a degree in alien studies.
#  answer: False
# Search query: Students must submit a thesis on the history of magic.
#  answer: False
# Search query: The university provides free weekly yoga classes for all students.
#  answer: False
# Search query: Students can enroll in a degree program for telepathy.
#  answer: False
# Search query: The university offers a degree in folklore studies.
#  answer: False
# Search query: Students must take a course on ancient mythology.
#  answer: False
# Search query: The university has a program for studying ancient ruins.
#  answer: False
# Search query: Students can take a course in advanced pottery.
#  answer: False
# Search query: The university offers a degree in extraterrestrial biology.
#  answer: False
# Search query: Students must complete a project on the history of fairytales.
#  answer: False
# Search query: The university provides a degree in historical reenactment.
#  answer: False
# Search query: Students can participate in a program for extreme sports.
#  answer: False
# Search query: The university offers a degree in mythological creatures.
#  answer: False
# Search query: Students must take a course on the history of Atlantis.
#  answer: False
# Search query: The university has a program for studying the Loch Ness Monster.
#  answer: False
# Search query: Students can enroll in a program for professional juggling.
#  answer: False
# Search query: The university offers a degree in circus arts.
#  answer: False
# Search query: Students must complete a research project on the history of unicorns.
#  answer: False
# Search query: The university provides free daily swimming lessons.
#  answer: False
# Search query: Students can participate in a program for parkour.
#  answer: False
# Search query: The university offers a degree in ghost studies.
#  answer: False
# Search query: Students must take a course on the sociology of werewolves.
#  answer: False
# Search query: Verifying if the university offers a degree in culinary arts.
#  answer: False
# Search query: Checking if students need to pass a swimming test to graduate.
#  answer: False
# Search query: Confirming that the university offers a major in marine biology.
#  answer: False
# Search query: Ensuring that students can apply for a pilot training program at the university.
#  answer: True
# Search query: Verifying that the university has a campus in Antarctica.
#  answer: False
# Search query: Checking if students are required to take a course in classical Latin.
#  answer: False
# Search query: Confirming that the university provides free daily transportation to New York City.
#  answer: False
# Search query: Ensuring that the university has a partnership with NASA for space exploration programs.
#  answer: False
# Search query: Verifying that students can major in agricultural engineering.
#  answer: False
# Search query: Checking if the university offers a course in underwater basket weaving.
#  answer: False
# Search query: Confirming that students must complete a scuba diving certification as part of their degree.
#  answer: False
# Search query: Ensuring that the university provides free housing for all international students.
#  answer: False
# Search query: Verifying that students need to complete an internship at the United Nations.
#  answer: False
# Search query: Checking if the university offers a Ph.D. in marine archaeology.
#  answer: False
# Search query: Confirming that students can take a course on the history of Atlantis.
#  answer: False
# Search query: Ensuring that the university has a 3D printing lab for creating sculptures of historical figures.
#  answer: False
# Search query: Verifying that students are required to study abroad in Australia for at least one semester.
#  answer: False
# Search query: Checking if the university provides courses in advanced telekinesis.
#  answer: False
# Search query: Confirming that students can major in cryptozoology.
#  answer: False
# Search query: Ensuring that the university offers a course on extraterrestrial communication.
#  answer: False
# Search query: Verifying that students must submit a research paper on the theory of flat Earth.
#  answer: False
# Search query: Checking if the university has a program focused on the study of unicorns.
#  answer: False
# Search query: Confirming that students can participate in a yearly trip to the Bermuda Triangle.
#  answer: False
# Search query: Ensuring that the university offers a degree in interstellar travel engineering.
#  answer: False
# Search query: Verifying that students are required to complete a 10-year time capsule project.
#  answer: False
# Search query: Checking if the university provides free daily yoga classes in space suits.
#  answer: False
# Search query: Confirming that students can attend lectures given by talking robots.
#  answer: False
# Search query: Ensuring that the university has a campus located on a floating island.
#  answer: False
# Search query: Verifying that students need to learn the Elvish language from "The Lord of the Rings".
#  answer: False
# Search query: Checking if the university offers courses in dragon taming.
#  answer: False
# Search query: Confirming that students must complete a summer course on the beaches of the Maldives.
#  answer: False
# Search query: Ensuring that the university has a minor in underwater archaeology.
#  answer: False
# Search query: Verifying that students are required to take a course in mime.
#  answer: False
# Search query: Checking if the university offers a program in time travel studies.
#  answer: False
# Search query: Confirming that students must submit a thesis on the history of magic.
#  answer: False
# Search query: Ensuring that the university provides free surfing lessons to all students.
#  answer: False
# Search query: Verifying that students can enroll in a degree program for parkour training.
#  answer: False
# Search query: Checking if the university offers a course on the history of Atlantis.
#  answer: False
# Search query: Confirming that students must complete an archaeological dig in Egypt.
#  answer: False
# Search query: Ensuring that the university offers a certificate in ghost hunting.
#  answer: False

# %%
outans = []
with open('out_of_data.txt', 'r') as file:
  for line in file:
    question = line.strip()
    try:
      answer = chain.invoke(({"question": question}))
    except Exception as e:
      answer = "err"
    print( " answer: " + answer)
    outans.append(answer)

with open("outofans.txt", 'w') as f:
    for item in outans:
        f.write("%s\n" % item)
# Out:
# Search query: The applicant has completed a course in machine learning.
#  answer: False
# Search query: The applicant has completed a course in artificial intelligence.
#  answer: False
# Search query: The applicant has a certificate in cloud computing.
#  answer: False
# Search query: The applicant has published a research paper in a technical journal.
#  answer: False
# Search query: The applicant has work experience in software development.
#  answer: False
# Search query: The applicant has a certification in cybersecurity.
#  answer: False
# Search query: The applicant has completed a course in big data analytics.
#  answer: False
# Search query: The applicant has participated in a hackathon.
#  answer: False
# Search query: The applicant has experience with machine learning frameworks.
#  answer: False
# Search query: The applicant has developed an open-source project.
#  answer: False
# Search query: The applicant has completed an internship in a tech company.
#  answer: False
# Search query: The applicant has knowledge of multiple programming languages.
#  answer: False
# Search query: The applicant has participated in a coding bootcamp.
#  answer: False
# Search query: The applicant has experience in data analysis.
#  answer: False
# Search query: The applicant has completed a course in web development.
#  answer: False
# Search query: The applicant has a certification in network security.
#  answer: False
# Search query: The applicant has contributed to a technical blog.
#  answer: False
# Search query: The applicant has completed a course in mobile app development.
#  answer: False
# Search query: The applicant has attended a technical conference.
#  answer: False
# Search query: The applicant has participated in an online coding challenge.
#  answer: False
# Search query: The applicant has experience with database management systems other than those listed.
#  answer: False
# Search query: The applicant has worked on a group project in a tech course.
#  answer: True
# Search query: The applicant has a minor in information technology.
#  answer: False
# Search query: The applicant has developed a mobile application.
#  answer: False
# Search query: The applicant has experience in cloud computing platforms.
#  answer: False
# Search query: The applicant has completed a project in artificial intelligence.
#  answer: False
# Search query: The applicant has a publication in a conference proceeding.
#  answer: False
# Search query: The applicant has a minor in software engineering.
#  answer: False
# Search query: The applicant has participated in a data science competition.
#  answer: False
# Search query: The applicant has completed a course in software testing.
#  answer: False
# Search query: The applicant has knowledge of artificial neural networks.
#  answer: False
# Search query: The applicant has completed a course in operating systems.
#  answer: False
# Search query: The applicant has experience with version control systems.
#  answer: False
# Search query: The applicant has completed a research project in computer science.
#  answer: True
# Search query: The applicant has a minor in cybersecurity.
#  answer: False
# Search query: The applicant has developed a software tool for data analysis.
#  answer: False
# Search query: The applicant has completed a course in human-computer interaction.
#  answer: False
# Search query: The applicant has participated in an online course in computer science.
#  answer: False
# Search query: The applicant has experience with IoT devices.
#  answer: False
# Search query: The applicant has completed a project in machine learning.
#  answer: False
# Search query: The applicant has knowledge of distributed computing.
#  answer: False
# Search query: The applicant has experience in developing scalable applications.
#  answer: False
# Search query: The applicant has a minor in data science.
#  answer: False
# Search query: The applicant has completed a certification in ethical hacking.
#  answer: False
# Search query: The applicant has developed a blockchain application.
#  answer: False
# Search query: The applicant has completed a course in computer graphics.
#  answer: False
# Search query: The applicant has knowledge of computer vision techniques.
#  answer: False
# Search query: The applicant has experience with augmented reality development.
#  answer: False
# Search query: The applicant has participated in a workshop on software development.
#  answer: False
# Search query: The applicant has experience in developing RESTful APIs.
#  answer: False
# Search query: The applicant has a minor in artificial intelligence.
#  answer: False
# Search query: The applicant has completed a course in quantum computing.
#  answer: False
# Search query: The applicant has a certification in project management.
#  answer: False
# Search query: The applicant has developed a virtual reality application.
#  answer: False
# Search query: The applicant has knowledge of software engineering methodologies.
#  answer: True
# Search query: The applicant has completed a course in software architecture.
#  answer: False
# Search query: The applicant has experience with cloud-native development.
#  answer: False
# Search query: The applicant has completed a course in network programming.
#  answer: False
# Search query: The applicant has knowledge of deep learning frameworks.
#  answer: False
# Search query: The applicant has completed a certification in DevOps.
#  answer: False
# Search query: The applicant has developed a software application for a research project.
#  answer: False
# Search query: The applicant has knowledge of agile software development.
#  answer: True
# Search query: The applicant has completed a course in computational biology.
#  answer: False
# Search query: The applicant has experience with edge computing.
#  answer: False
# Search query: The applicant has completed a course in robotics.
#  answer: False
# Search query: The applicant has a minor in human-computer interaction.
#  answer: False
# Search query: The applicant has developed a natural language processing application.
#  answer: False
# Search query: The applicant has completed a course in software project management.
#  answer: False
# Search query: The applicant has knowledge of bioinformatics.
#  answer: False
# Search query: The applicant has completed a course in mobile robotics.
#  answer: False
# Search query: The applicant has experience with software-defined networking.
#  answer: False
# Search query: The applicant has completed a course in cybersecurity management.
#  answer: False
# Search query: The applicant has developed a machine learning model.
#  answer: False
# Search query: The applicant has knowledge of quantum cryptography.
#  answer: False
# Search query: The applicant has completed a course in embedded systems.
#  answer: False
# Search query: The applicant has developed a real-time application.
#  answer: False
# Search query: The applicant has experience in game development.
#  answer: False
# Search query: The applicant has completed a course in computational neuroscience.
#  answer: False
# Search query: The applicant has knowledge of virtual reality development.
#  answer: False
# Search query: The applicant has completed a course in digital forensics.
#  answer: False
# Search query: The applicant has developed a chatbot.
#  answer: False
# Search query: The applicant has experience in high-performance computing.
#  answer: False
# Search query: The applicant has completed a course in natural language processing.
#  answer: False
# Search query: The applicant has knowledge of autonomous systems.
#  answer: False
# Search query: The applicant has completed a course in cognitive computing.
#  answer: False
# Search query: The applicant has developed a software prototype for a startup.
#  answer: False
# Search query: The applicant has experience in conducting usability testing.
#  answer: False
# Search query: The applicant has completed a course in bioinformatics.
#  answer: False
# Search query: The applicant has knowledge of software verification and validation.
#  answer: False
# Search query: The applicant has completed a course in distributed systems.
#  answer: False
# Search query: The applicant has developed a software solution for healthcare.
#  answer: False
# Search query: The applicant has experience in smart city projects.
#  answer: False
# Search query: The applicant has completed a course in cybersecurity for critical infrastructure.
#  answer: False
# Search query: The applicant has knowledge of robotics programming.
#  answer: False
# Search query: The applicant has developed a software application for environmental monitoring.
#  answer: False
# Search query: The applicant has experience with blockchain technology.
#  answer: False
# Search query: The applicant has completed a course in software process improvement.
#  answer: False
# Search query: The applicant has knowledge of wearable computing.
#  answer: False
# Search query: The applicant has completed a course in cyber-physical systems.
#  answer: False
# Search query: The applicant has developed a software application for smart homes.
#  answer: False
# Search query: Students need to take an English proficiency test if their primary language is not English.
#  answer: True
# Search query: Students can apply for on-campus housing through the university's housing portal.
#  answer: True
# Search query: Students are required to attend an orientation session upon arrival on campus.
#  answer: False
# Search query: The university provides academic advising services for international students.
#  answer: True
# Search query: International students are eligible for scholarships and financial aid through the university.
#  answer: True
# Search query: The university offers cultural exchange programs for international students.
#  answer: False
# Search query: Students need to complete a financial affidavit to prove their ability to cover tuition and living expenses.
#  answer: True
# Search query: International students are required to check-in with the International Office upon arrival.
#  answer: True
# Search query: Students can participate in university clubs and organizations.
#  answer: True
# Search query: The university offers language support services for non-native English speakers.
#  answer: True
# Search query: International students are required to maintain full-time enrollment status.
#  answer: True
# Search query: Students can work part-time on-campus during their studies.
#  answer: True
# Search query: The university provides airport pick-up services for new international students.
#  answer: False
# Search query: International students need to submit their transcripts for evaluation before admission.
#  answer: True
# Search query: Students can use the university's health services for routine medical care.
#  answer: False
# Search query: The university organizes social events specifically for international students.
#  answer: False
# Search query: Students need to renew their student visa annually.
#  answer: False
# Search query: International students are required to have a local bank account.
#  answer: False
# Search query: Students can apply for off-campus housing through the university.
#  answer: False
# Search query: The university requires a mandatory internship for all international students.
#  answer: False
# Search query: International students can bring dependents who will also be provided with health insurance.
#  answer: False
# Search query: Students can transfer credits from their home country's institutions.
#  answer: False
# Search query: The university has a buddy program to help new international students adjust.
#  answer: False
# Search query: International students are allowed to stay on campus during holidays.
#  answer: False
# Search query: Students need to submit proof of previous education in a STEM field for the MS-ACS program.
#  answer: True
# Search query: The university provides career counseling services for international students.
#  answer: False
# Search query: International students need to pay a one-time enrollment fee upon arrival.
#  answer: False
# Search query: Students are required to submit a letter of recommendation from their home country's education authority.
#  answer: False
# Search query: The university provides insurance coverage for travel to and from the student's home country.
#  answer: False
# Search query: Students need to complete a background check before admission.
#  answer: False
# Search query: The university offers mentorship programs for international students.
#  answer: False
# Search query: Students are required to attend workshops on academic integrity.
#  answer: False
# Search query: The university has a dedicated support group for international students.
#  answer: True
# Search query: Students can access mental health services on campus.
#  answer: True
# Search query: The university offers a preparatory course for international students before the start of the semester.
#  answer: False
# Search query: Students need to provide a medical report from their home country.
#  answer: False
# Search query: The university has a 24/7 emergency contact for international students.
#  answer: err
# Search query: Students are required to have a health insurance plan that meets the university's requirements.
#  answer: True
# Search query: The university offers a language exchange program.
#  answer: False
# Search query: Students can take elective courses outside the MS-ACS program.
#  answer: True
# Search query: International students are required to attend regular check-ins with their academic advisor.
#  answer: False
# Search query: The university provides support for obtaining necessary visas and permits.
#  answer: False
# Search query: Students can apply for research assistant positions.
#  answer: True
# Search query: The university has partnerships with local businesses for internship opportunities.
#  answer: False
# Search query: International students are required to file their taxes in the host country.
#  answer: False
# Search query: Students need to participate in a community service project.
#  answer: False
# Search query: The university offers workshops on resume writing and job interviews.
#  answer: True
# Search query: Students need to submit a personal statement as part of their application.
#  answer: False
# Search query: The university provides support for adjusting to the local culture.
#  answer: False
# Search query: Students are required to take a course on research methodologies.
#  answer: False
# Search query: The university offers online resources and webinars for international students.
#  answer: False
# Search query: Students can join the university's alumni network upon graduation.
#  answer: True
# Search query: International students need to obtain a local driving license if they plan to drive.
#  answer: False
# Search query: The university has a writing center to help students with their assignments.
#  answer: True
# Search query: Students need to maintain a minimum GPA to remain in the MS-ACS program.
#  answer: True
# Search query: The university provides translation services for official documents.
#  answer: False
# Search query: Students can participate in study groups organized by the university.
#  answer: True
# Search query: The university offers workshops on intercultural communication.
#  answer: False
# Search query: Students need to attend safety and security briefings.
#  answer: False
# Search query: The university has a student union that represents international students.
#  answer: False
# Search query: Students can access online learning resources through the university's library.
#  answer: True
# Search query: International students need to register with the local municipality upon arrival.
#  answer: False
# Search query: The university offers training on academic writing and citation.
#  answer: False
# Search query: Students are required to complete a capstone project as part of the MS-ACS program.
#  answer: True
# Search query: The university provides support for opening a local bank account.
#  answer: False
# Search query: Students need to complete a course on professional ethics.
#  answer: True
# Search query: The university has an international student ambassador program.
#  answer: True
# Search query: Students can access language learning software through the university.
#  answer: True
# Search query: International students need to comply with local labor laws if they work part-time.
#  answer: False
# Search query: The university provides information sessions on postgraduate opportunities.
#  answer: False
# Search query: Students need to submit a copy of their passport with their application.
#  answer: True
# Search query: The university offers workshops on stress management and wellbeing.
#  answer: False
# Search query: Students can participate in extracurricular activities organized by the university.
#  answer: True
# Search query: The university provides a directory of local services and amenities.
#  answer: False
# Search query: Students need to submit proof of immunizations before starting their studies.
#  answer: False
# Search query: The university offers workshops on time management and study skills.
#  answer: False
# Search query: Students can access the university's online portal for academic resources.
#  answer: True
# Search query: International students need to follow the university's code of conduct.
#  answer: False
# Search query: The university offers a peer mentoring program for new students.
#  answer: False
# Search query: Students need to attend seminars on career development.
#  answer: True
# Search query: The university provides information on local transportation options.
#  answer: False
# Search query: Students are required to have a local phone number for emergency contact.
#  answer: False
# Search query: The university offers workshops on public speaking and presentation skills.
#  answer: False
# Search query: Students can use the university's sports facilities.
#  answer: True
# Search query: The university provides assistance with legal issues related to student status.
#  answer: False
# Search query: Students need to participate in team-building activities.
#  answer: False
# Search query: The university offers courses on entrepreneurship and innovation.
#  answer: False
# Search query: Students need to submit an academic reference with their application.
#  answer: False
# Search query: The university provides financial literacy workshops.
#  answer: False
# Search query: Students can join professional associations related to their field of study.
#  answer: True
# Search query: The university offers a service learning program.
#  answer: False
# Search query: Students need to complete a survey on their experience at the end of the program.
#  answer: False
# Search query: The university provides guidance on applying for postgraduate programs.
#  answer: True
# Search query: Students can access virtual career fairs organized by the university.
#  answer: True
# Search query: The university offers online courses for continuing education.
#  answer: True
# Search query: Students need to submit a portfolio of their previous work with their application.
#  answer: False
# Search query: The university provides support for finding off-campus housing.
#  answer: True
# Search query: Students can access the university's online job board.
#  answer: True
# Search query: The university offers courses on global issues and international relations.
#  answer: False
# Search query: Students need to attend diversity and inclusion workshops.
#  answer: False
# Search query: The university provides assistance with finding local volunteer opportunities.
#  answer: False
# Search query: Students can access the university's online learning management system.
#  answer: True
# Search query: The university offers a course on sustainable development.
#  answer: False
# Search query: Students need to complete a digital literacy course.
#  answer: False
# Search query: The university provides information on local cultural events.
#  answer: False
# Search query: Students can participate in exchange programs with partner universities.
#  answer: False
# Search query: The university offers a global leadership program.
#  answer: False
# Search query: Students need to submit a writing sample with their application.
#  answer: True
# Search query: The university provides resources for improving academic English.
#  answer: False
# Search query: Students can access the university's online bookstore.
#  answer: True
# Search query: The university offers a certificate program in project management.
#  answer: False
# Search query: Students need to attend workshops on digital research skills.
#  answer: False
# Search query: The university provides support for developing business plans.
#  answer: False
# Search query: Students can participate in hackathons organized by the university.
#  answer: True
# Search query: The university offers training on data analysis and visualization.
#  answer: False
# Search query: Students need to complete a course on critical thinking.
#  answer: False
# Search query: The university provides access to online academic journals.
#  answer: False
# Search query: Students can use the university's virtual reality lab.
#  answer: False
# Search query: The university offers a course on ethics in technology.
#  answer: False
# Search query: Students need to submit an academic progress report each semester.
#  answer: False
# Search query: The university provides access to online workshops on academic writing.
#  answer: False
# Search query: Students can participate in university-led field trips.
#  answer: False
# Search query: The university offers a digital innovation lab.
#  answer: False
# Search query: Students need to complete a course on global communication.
#  answer: False
# Search query: The university provides support for obtaining patents.
#  answer: False
# Search query: Students can join interdisciplinary research projects.
#  answer: True
# Search query: The university offers a course on artificial intelligence.
#  answer: False
# Search query: Students need to attend workshops on grant writing.
#  answer: False
# Search query: The university provides resources for studying abroad.
#  answer: False
# Search query: Students can participate in the university's incubator program.
#  answer: True
# Search query: The university offers a program on social entrepreneurship.
#  answer: False
# Search query: Students need to complete a course on financial management.
#  answer: False
# Search query: The university provides access to online career counseling.
#  answer: False
# Search query: Students can participate in student government.
#  answer: False
# Search query: The university offers a program on environmental sustainability.
#  answer: False
# Search query: Students need to attend workshops on leadership development.
#  answer: False
# Search query: The university provides resources for learning new languages.
#  answer: False
# Search query: Students can access the university's cloud computing resources.
#  answer: True
# Search query: The university offers courses on blockchain technology.
#  answer: False
# Search query: Students need to complete a professional development plan.
#  answer: False
# Search query: The university provides access to online simulations and virtual labs.
#  answer: False
# Search query: Students can participate in collaborative research with faculty.
#  answer: True
# Search query: The university offers a course on human-computer interaction.
#  answer: True
# Search query: Students need to attend workshops on conflict resolution.
#  answer: False
# Search query: The university provides support for securing internships.
#  answer: True
# Search query: Students can participate in design thinking workshops.
#  answer: False
# Search query: The university offers a program on data privacy and security.
#  answer: False
# Search query: Students need to submit a project proposal as part of their coursework.
#  answer: True
# Search query: The university provides access to digital media production tools.
#  answer: False
# Search query: Students can participate in university-sponsored hackathons.
#  answer: True
# Search query: The university offers a course on big data analytics.
#  answer: True
# Search query: Students need to attend workshops on networking skills.
#  answer: False
# Search query: The university provides support for developing academic portfolios.
#  answer: False
# Search query: Students can access the university's makerspace.
#  answer: False
# Search query: The university offers a course on cloud computing and virtualization.
#  answer: False
# Search query: Students need to complete a case study as part of their coursework.
#  answer: False
# Search query: The university provides access to online databases and research tools.
#  answer: True
# Search query: Students can participate in faculty-led research initiatives.
#  answer: False
# Search query: The university offers a program on digital marketing.
#  answer: False
# Search query: Students need to attend workshops on academic publishing.
#  answer: False
# Search query: The university provides support for developing research proposals.
#  answer: True
# Search query: Students can access online tutorials on software tools.
#  answer: True
# Search query: The university offers a course on cybersecurity.
#  answer: False
# Search query: Students need to complete a literature review as part of their coursework.
#  answer: False
# Search query: The university provides resources for writing grant applications.
#  answer: False
# Search query: Students can participate in innovation challenges organized by the university.
#  answer: True
# Search query: The university offers a program on machine learning.
#  answer: False
# Search query: Students need to submit a mid-term report on their project progress.
#  answer: False
# Search query: The university provides access to online training in statistical analysis.
#  answer: False
# Search query: Students can participate in international conferences sponsored by the university.
#  answer: False
# Search query: The university offers a course on digital transformation.
#  answer: False
# Search query: Students need to complete a collaborative project as part of their coursework.
#  answer: True
# Search query: The university provides support for creating digital portfolios.
#  answer: False
# Search query: Students can access the university's online resource center.
#  answer: True
# Search query: The university offers a program on innovation management.
#  answer: False
# Search query: Students need to attend workshops on personal branding.
#  answer: False
# Search query: The university provides resources for understanding research ethics.
#  answer: True
# Search query: Students can participate in industry-sponsored projects.
#  answer: True
# Search query: The university offers a course on business analytics.
#  answer: False
# Search query: Students need to submit a research plan as part of their coursework.
#  answer: False
# Search query: The university provides access to virtual learning environments.
#  answer: True
# Search query: Students can participate in professional development seminars.
#  answer: True
# Search query: The university offers a program on digital innovation.
#  answer: False
# Search query: Students need to attend workshops on project management.
#  answer: False
# Search query: The university provides support for developing presentations and pitches.
#  answer: True
# Search query: Students can access the university's online collaboration tools.
#  answer: True
# Search query: The university offers a course on digital entrepreneurship.
#  answer: False
# Search query: Students need to complete a research internship as part of their coursework.
#  answer: False
# Search query: The university provides access to online resources for academic research.
#  answer: True
# Search query: Students can participate in university-led innovation competitions.
#  answer: True
# Search query: The university offers a program on digital strategy.
#  answer: False
# Search query: Students need to attend workshops on effective communication.
#  answer: False
# Search query: The university provides support for creating research posters.
#  answer: False
# Search query: Students can access the university's digital library resources.
#  answer: True
# Search query: The university offers a course on data science.
#  answer: True
# Search query: Students need to complete a project on emerging technologies.
#  answer: True
# Search query: The university provides resources for conducting literature reviews.
#  answer: False
# Search query: Students can participate in university-led service projects.
#  answer: False
# Search query: The university offers a program on digital media.
#  answer: False
# Search query: Students need to attend workshops on scientific writing.
#  answer: False
# Search query: Verifying that the Graduate Directed Project includes version control systems like Git.
#  answer: False
# Search query: Checking if the Graduate Directed Project requires students to use Agile methodologies.
#  answer: True
# Search query: Confirming that the project includes code reviews and peer programming sessions.
#  answer: True
# Search query: Ensuring that students must present their project progress to the faculty committee periodically.
#  answer: True
# Search query: Verifying that students need to create a detailed project plan and timeline.
#  answer: True
# Search query: Checking if the project involves risk management and mitigation planning.
#  answer: False
# Search query: Confirming that students use project management tools like JIRA or Trello.
#  answer: False
# Search query: Ensuring that students conduct regular team meetings and status updates.
#  answer: True
# Search query: Verifying that students must document their project using technical writing standards.
#  answer: True
# Search query: Checking if students perform usability testing on their project.
#  answer: False
# Search query: Confirming that the project includes performance testing and optimization.
#  answer: False
# Search query: Ensuring that students must create a deployment plan for their project.
#  answer: True
# Search query: Verifying that students need to maintain a project log or journal.
#  answer: True
# Search query: Checking if the project includes integration testing with other systems.
#  answer: False
# Search query: Confirming that students must develop a maintenance plan for their project.
#  answer: False
# Search query: Ensuring that students need to present their final project to a panel of experts.
#  answer: True
# Search query: Verifying that the project includes compliance with relevant industry standards.
#  answer: False
# Search query: Checking if students must create user manuals and documentation.
#  answer: False
# Search query: Confirming that students need to handle project budgeting and cost estimation.
#  answer: False
# Search query: Ensuring that the project includes security and data protection measures.
#  answer: False
# Search query: Verifying that students must conduct a project post-mortem analysis.
#  answer: False
# Search query: Checking if students are required to create mockups and wireframes during the design phase.
#  answer: True
# Search query: Confirming that students need to use continuous integration and delivery (CI/CD) pipelines.
#  answer: err
# Search query: Ensuring that students conduct stakeholder interviews and gather feedback.
#  answer: True
# Search query: Verifying that students must develop and execute test plans.
#  answer: True
# Search query: Checking if the project includes scalability planning.
#  answer: False
# Search query: Confirming that students need to adhere to coding standards and guidelines.
#  answer: False
# Search query: Ensuring that students perform regular code refactoring and optimization.
#  answer: True
# Search query: Verifying that students must create API documentation if applicable.
#  answer: False
# Search query: Checking if students need to use data modeling and database design techniques.
#  answer: True
# Search query: Confirming that students must include error handling and logging in their project.
#  answer: False
# Search query: Ensuring that students conduct market research as part of the project.
#  answer: False

# %%
relact = []

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.34.0-py2.py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.11.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 21.7 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: watchdog, smmap, pydeck, gitdb, gitpython, streamlit
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 pydeck-0.9.1 smmap-5.0.1 streamlit-1.34.0 watchdog-4.0.0

# %%
answerquery("My undergraduate degree is from electronics, what all the prerequisites do I need to finish for MSACS degree ?")
# Out:
# Search query: My undergraduate degree is from electronics, what all the prerequisites do I need to finish for MSACS degree ?
# 'If your undergraduate degree is in electronics, you will need to complete prerequisites in data structures, computer networks or network fundamentals, database systems, discrete mathematics, and statistics for the MSACS degree.'

# %%
answerquery("My undergraduate degree is from computer science, what all the prerequisites do I need to finish for MSACS degree ?")
# Out:
# Search query: My undergraduate degree is from computer science, what all the prerequisites do I need to finish for MSACS degree ?
# 'If your undergraduate degree is in computer science, you would need to complete prerequisites in data structures, computer networks or network fundamentals, database systems, discrete mathematics, and statistics for the MSACS degree.'

# %%
# %%writefile main.py

from langchain_core.runnables import (
    RunnableBranch,
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from typing import Tuple, List, Optional
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser
import os
from langchain_community.graphs import Neo4jGraph
from langchain.text_splitter import TokenTextSplitter
from langchain_openai import ChatOpenAI
from langchain_experimental.graph_transformers import LLMGraphTransformer
from neo4j import GraphDatabase
from yfiles_jupyter_graphs import GraphWidget
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores.neo4j_vector import remove_lucene_chars
from langchain_core.runnables import ConfigurableField, RunnableParallel, RunnablePassthrough


try:
  import google.colab
  from google.colab import output
  output.enable_custom_widget_manager()
except:
  pass

os.environ["OPENAI_API_KEY"] = "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"
os.environ["NEO4J_URI"] = "bolt+s://d66e8589.databases.neo4j.io:7687"
os.environ["NEO4J_USERNAME"] = "neo4j"
os.environ["NEO4J_PASSWORD"] = "QAChatbot"
_search_query = RunnableLambda(lambda x : x["question"])


graph = Neo4jGraph()

llm=ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-0125") # gpt-4-0125-preview occasionally has issues
llm_transformer = LLMGraphTransformer(llm=llm)

vector_index = Neo4jVector.from_existing_graph(
    OpenAIEmbeddings(),
    search_type="hybrid",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding"
)


graph.query(
    "CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]")

# Extract entities from text
class Entities(BaseModel):
    """Identifying information about entities."""

    names: List[str] = Field(
        ...,
        description="All the courses, requirements, or business entities that "
        "appear in the text",
    )

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are extracting course, professors, requirements, project entities from the text.",
        ),
        (
            "human",
            "Use the given format to extract information from the following "
            "input: {question}",
        ),
    ]
)

entity_chain = prompt | llm.with_structured_output(Entities)

def generate_full_text_query(input: str) -> str:
    """
    Generate a full-text search query for a given input string.

    This function constructs a query string suitable for a full-text search.
    It processes the input string by splitting it into words and appending a
    similarity threshold (~2 changed characters) to each word, then combines
    them using the AND operator. Useful for mapping entities from user questions
    to database values, and allows for some misspelings.
    """
    full_text_query = ""
    words = [el for el in remove_lucene_chars(input).split() if el]
    for word in words[:-1]:
        full_text_query += f" {word}~2 AND"
    full_text_query += f" {words[-1]}~2"
    return full_text_query.strip()

# Fulltext index query
def structured_retriever(question: str) -> str:
    """
    Collects the neighborhood of entities mentioned
    in the question
    """
    result = ""
    entities = entity_chain.invoke({"question": question})
    for entity in entities.names:
        response = graph.query(
            """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
            YIELD node,score
            CALL {
              WITH node
              MATCH (node)-[r:!MENTIONS]->(neighbor)
              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output
              UNION ALL
              WITH node
              MATCH (node)<-[r:!MENTIONS]-(neighbor)
              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output
            }
            RETURN output LIMIT 50
            """,
            {"query": generate_full_text_query(entity)},
        )
        result += "\n".join([el['output'] for el in response])
    return result

def retriever(question: str):
    print(f"Search query: {question}")
    structured_data = structured_retriever(question)
    unstructured_data = [el.page_content for el in vector_index.similarity_search(question)]
    final_data = f""" Structured data: {structured_data} Unstructured data: {"#Document ". join(unstructured_data)}  """
    return final_data


def answerquery(question: str):
  template = """Answer the question based only on the following context:
  {context}

  Question: {question}
  Use natural language and be concise.
  Answer:"""
  prompt = ChatPromptTemplate.from_template(template)

  chain = (
      RunnableParallel(
          {
              "context": _search_query | retriever,
              "question": RunnablePassthrough(),
          }
      )
      | prompt
      | llm
      | StrOutputParser()
  )

  return chain.invoke(({"question": question}))

# %%
answerquery("I am a computer science undergraduate, what all the things i need to be prepared to be a successful graduate ?")
# Out:
# Search query: I am a computer science undergraduate, what all the things i need to be prepared to be a successful graduate ?
# 'As a computer science undergraduate, to be a successful graduate, you need to ensure you have completed coursework in data structures, computer networks, database systems, discrete mathematics, and statistics. Additionally, aim for a GRE score of 290 or higher, maintain a GPA of 3.0 or above, and have fewer than 7 backlogs. It is also beneficial to have completed a course in data structures and have a background in technical computing disciplines.'

# %%
with open('tests.txt', 'r') as file:
  for line in file:
    ques = line.strip()
    ans = answerquery(remove_lucene_chars(ques))
    print( " answer: " + ans)
# Out:
# Search query: "Does the MSACS program require 30 credits to finish the program if there are no prerequisites?"
#  answer: Yes, the MSACS program requires 30 credits to finish the program even if there are no prerequisites.
# Search query: "Does the MSACS program not require 35 credits to finish the program if there are no prerequisites?"
#  answer: The MSACS program does not require 35 credits to finish the program if there are no prerequisites.
# Search query: "Does the MSACS program require 35 credits to finish the program if there are no prerequisites?"
#  answer: The MSACS program does not require 35 credits to finish the program if there are no prerequisites.
# Search query: "Does the MSACS program not require 30 credits to finish the program if there are no prerequisites?"
#  answer: The MSACS program does require 30 credits to finish the program, even if there are no prerequisites.
# Search query: "Is Dr. Ajay Bandi the professor for the course 'Application Design: Patterns And Frameworks' in the MSACS program?"
#  answer: Yes, Dr. Ajay Bandi is the professor for the course 'Application Design: Patterns And Frameworks' in the MSACS program.
# Search query: "Is Dr. Isam Alobaidi not the professor for the course 'Data Visualization' in the MSACS program?"
#  answer: Dr. Isam Alobaidi is not the professor for the course 'Data Visualization' in the MSACS program.
# Search query: "Is Dr. Ajay Bandi the professor for the course 'Database Systems' in the MSACS program?"
#  answer: Yes.
# Search query: "Is Dr. Isam Alobaidi not the professor for the course 'Graduate Directed Project I' in the MSACS program?"
#  answer: Dr. Isam Alobaidi is not the professor for the course 'Graduate Directed Project I' in the MSACS program.
# Search query: "Does the course 'Mobile Computing: iOS' have 3 credit hours in the MSACS program?"
#  answer: Yes, the course 'Mobile Computing: iOS' has 3 credit hours in the MSACS program.
# Search query: "Does the course 'Graduate Directed Project I' not have 4 credit hours in the MSACS program?"
#  answer: No, the course 'Graduate Directed Project I' does not have 4 credit hours in the MSACS program.
# Search query: "Does the course 'Web Mining' have 4 credit hours in the MSACS program?"
#  answer: No, the course 'Web Mining' does not have 4 credit hours in the MSACS program.
# Search query: "Does the course 'Application Design: Patterns And Frameworks' not have 3 credit hours in the MSACS program?"
#  answer: The course 'Application Design: Patterns And Frameworks' does have 3 credit hours in the MSACS program.
# Search query: "Is 'Object-Oriented Programming' a required course in the MSACS program?"
#  answer: Yes, 'Object-Oriented Programming' is a required course in the MSACS program.
# Search query: "Is 'Database Systems' not a required course in the MSACS program?"
#  answer: "Database Systems" is a required course in the MSACS program.
# Search query: "Is 'Generative AI' a required course in the MSACS program?"
#  answer: No, "Generative AI" is not a required course in the MSACS program.
# Search query: "Is 'Object-Oriented Programming' not a required course in the MSACS program?"
#  answer: "Object-Oriented Programming" is a required course in the MSACS program.
# Search query: "If I didn't take Database in my undergrad, do I need to take a prerequisite course for the MSACS program?"
#  answer: Yes, if you didn't take Database in your undergrad, you need to take a prerequisite course for the MSACS program, which is 44-460 Database Systems.
# Search query: "If I took Database in my undergrad, do I not need to take a prerequisite course for the MSACS program?"
#  answer: If you took Database in your undergrad, you do not need to take a prerequisite course for the MSACS program.
# Search query: "If I took Database in my undergrad, do I need to take a prerequisite course for the MSACS program?"
#  answer: No, if you took Database in your undergrad, you do not need to take a prerequisite course for the MSACS program.
# Search query: "If I didn't take Database in my undergrad, do I not need to take a prerequisite course for the MSACS program?"
#  answer: If you didn't take Database in your undergrad, you will need to take a prerequisite course for the MSACS program.
# Search query: "Can prerequisites for the MSACS program be completed concurrently with required courses?"
#  answer: No, prerequisites for the MSACS program cannot be completed concurrently with required courses.
# Search query: "Does MSACS programs require four-year undergraduate degree to enroll?"
#  answer: Yes, the MSACS program requires a four-year undergraduate degree to enroll.
# Search query:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-7-98521afb4d93> in <cell line: 1>()
#       2   for line in file:
#       3     ques = line.strip()
# ----> 4     ans = answerquery(ques)
#       5     print( " answer: " + ans)
#
# /content/gdrive/MyDrive/main.py in answerquery(question)
#     156   )
#     157
# --> 158   return chain.invoke(({"question": question}))
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config)
#    2391         try:
#    2392             for i, step in enumerate(self.steps):
# -> 2393                 input = step.invoke(
#    2394                     input,
#    2395                     # mark each step as a child run
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config)
#    3034                     for key, step in steps.items()
#    3035                 ]
# -> 3036                 output = {key: future.result() for key, future in zip(steps, futures)}
#    3037         # finish the root run
#    3038         except BaseException as e:
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/base.py in <dictcomp>(.0)
#    3034                     for key, step in steps.items()
#    3035                 ]
# -> 3036                 output = {key: future.result() for key, future in zip(steps, futures)}
#    3037         # finish the root run
#    3038         except BaseException as e:
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     456                     raise CancelledError()
#     457                 elif self._state == FINISHED:
# --> 458                     return self.__get_result()
#     459                 else:
#     460                     raise TimeoutError()
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/lib/python3.10/concurrent/futures/thread.py in run(self)
#      56
#      57         try:
# ---> 58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config)
#    2391         try:
#    2392             for i, step in enumerate(self.steps):
# -> 2393                 input = step.invoke(
#    2394                     input,
#    2395                     # mark each step as a child run
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3855         """Invoke this runnable synchronously."""
#    3856         if hasattr(self, "func"):
# -> 3857             return self._call_with_config(
#    3858                 self._invoke,
#    3859                 input,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/base.py in _call_with_config(self, func, input, config, run_type, **kwargs)
#    1501             output = cast(
#    1502                 Output,
# -> 1503                 context.run(
#    1504                     call_func_with_variable_args,  # type: ignore[arg-type]
#    1505                     func,  # type: ignore[arg-type]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/config.py in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     344     if run_manager is not None and accepts_run_manager(func):
#     345         kwargs["run_manager"] = run_manager
# --> 346     return func(input, **kwargs)  # type: ignore[call-arg]
#     347
#     348
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/base.py in _invoke(self, input, run_manager, config, **kwargs)
#    3729                         output = chunk
#    3730         else:
# -> 3731             output = call_func_with_variable_args(
#    3732                 self.func, input, config, run_manager, **kwargs
#    3733             )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/runnables/config.py in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     344     if run_manager is not None and accepts_run_manager(func):
#     345         kwargs["run_manager"] = run_manager
# --> 346     return func(input, **kwargs)  # type: ignore[call-arg]
#     347
#     348
#
# /content/gdrive/MyDrive/main.py in retriever(question)
#     130     print(f"Search query: {question}")
#     131     structured_data = structured_retriever(question)
# --> 132     unstructured_data = [el.page_content for el in vector_index.similarity_search(question)]
#     133     final_data = f""" Structured data: {structured_data} Unstructured data: {"#Document ". join(unstructured_data)}  """
#     134     return final_data
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/neo4j_vector.py in similarity_search(self, query, k, params, filter, **kwargs)
#     915         """
#     916         embedding = self.embedding.embed_query(text=query)
# --> 917         return self.similarity_search_by_vector(
#     918             embedding=embedding,
#     919             k=k,
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/neo4j_vector.py in similarity_search_by_vector(self, embedding, k, filter, **kwargs)
#    1076             List of Documents most similar to the query vector.
#    1077         """
# -> 1078         docs_and_scores = self.similarity_search_with_score_by_vector(
#    1079             embedding=embedding, k=k, filter=filter, **kwargs
#    1080         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/neo4j_vector.py in similarity_search_with_score_by_vector(self, embedding, k, filter, params, **kwargs)
#    1042         }
#    1043
# -> 1044         results = self.query(read_query, params=parameters)
#    1045
#    1046         docs = [
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/neo4j_vector.py in query(self, query, params)
#     607             try:
#     608                 data = session.run(query, params)
# --> 609                 return [r.data() for r in data]
#     610             except CypherSyntaxError as e:
#     611                 raise ValueError(f"Cypher Statement is not valid\n{e}")
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/neo4j_vector.py in <listcomp>(.0)
#     607             try:
#     608                 data = session.run(query, params)
# --> 609                 return [r.data() for r in data]
#     610             except CypherSyntaxError as e:
#     611                 raise ValueError(f"Cypher Statement is not valid\n{e}")
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/work/result.py in __iter__(self)
#     268                 yield self._record_buffer.popleft()
#     269             elif self._streaming:
# --> 270                 self._connection.fetch_message()
#     271             elif self._discarding:
#     272                 self._discard()
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/io/_common.py in inner(*args, **kwargs)
#     176             def inner(*args, **kwargs):
#     177                 try:
# --> 178                     func(*args, **kwargs)
#     179                 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180                     assert not asyncio.iscoroutinefunction(self.__on_error)
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/io/_bolt.py in fetch_message(self)
#     848             hydration_hooks=self.responses[0].hydration_hooks
#     849         )
# --> 850         res = self._process_message(tag, fields)
#     851         self.idle_since = monotonic()
#     852         return res
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/io/_bolt5.py in _process_message(self, tag, fields)
#     367             self._server_state_manager.state = self.bolt_states.FAILED
#     368             try:
# --> 369                 response.on_failure(summary_metadata or {})
#     370             except (ServiceUnavailable, DatabaseUnavailable):
#     371                 if self.pool:
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/io/_common.py in on_failure(self, metadata)
#     243         handler = self.handlers.get("on_summary")
#     244         Util.callback(handler)
# --> 245         raise Neo4jError.hydrate(**metadata)
#     246
#     247     def on_ignored(self, metadata=None):
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureCallFailed} {message: Failed to invoke procedure `db.index.fulltext.queryNodes`: Caused by: org.apache.lucene.queryparser.classic.ParseException: Encountered "<EOF>" at line 1, column 0.
# Was expecting one of:
#     <NOT> ...
#     "+" ...
#     "-" ...
#     <BAREOPER> ...
#     "(" ...
#     "*" ...
#     <QUOTED> ...
#     <TERM> ...
#     <PREFIXTERM> ...
#     <WILDTERM> ...
#     <REGEXPTERM> ...
#     "[" ...
#     "{" ...
#     <NUMBER> ...
#     <TERM> ...
#     }

# %%
# %%writefile app.py

import streamlit as st
from main import answerquery

st.title("NWMSU QA Chatbot")

# Initialize chat history
if "messages" not in st.session_state:
    st.session_state.messages = []

# Display chat messages from history on app rerun
for message in st.session_state.messages:
    with st.chat_message(message["role"]):
        st.markdown(message["content"])

# React to user input
if prompt := st.text_input("What is up?"):
    # Display user message in chat message container
    st.chat_message("user").markdown(prompt)
    # Add user message to chat history
    st.session_state.messages.append({"role": "user", "content": prompt})

    response = answerquery(prompt)
    # Display assistant response in chat message container
    with st.chat_message("assistant"):
        st.markdown(response)
    # Add assistant response to chat history
    st.session_state.messages.append({"role": "assistant", "content": response})
# Out:
# 2024-05-23 07:47:51.044
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2024-05-23 07:47:51.074 Session state does not function when running a script without `streamlit run`
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/session_state.py in __getitem__(self, key)
#     410         try:
# --> 411             return self._getitem(widget_id, key)
#     412         except KeyError:
#
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/session_state.py in _getitem(self, widget_id, user_key)
#     455         # We'll never get here
# --> 456         raise KeyError
#     457
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/session_state_proxy.py in __getattr__(self, key)
#     118         try:
# --> 119             return self[key]
#     120         except KeyError:
#
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/session_state_proxy.py in __getitem__(self, key)
#      89         require_valid_user_key(key)
# ---> 90         return get_session_state()[key]
#      91
#
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/safe_session_state.py in __getitem__(self, key)
#      92         with self._lock:
# ---> 93             return self._state[key]
#      94
#
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/session_state.py in __getitem__(self, key)
#     412         except KeyError:
# --> 413             raise KeyError(_missing_key_error_message(key))
#     414
#
# KeyError: 'st.session_state has no key "messages". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6772d18077e5> in <cell line: 13>()
#      11
#      12 # Display chat messages from history on app rerun
# ---> 13 for message in st.session_state.messages:
#      14     with st.chat_message(message["role"]):
#      15         st.markdown(message["content"])
#
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/session_state_proxy.py in __getattr__(self, key)
#     119             return self[key]
#     120         except KeyError:
# --> 121             raise AttributeError(_missing_attr_error_message(key))
#     122
#     123     @gather_metrics("session_state.set_attr")
#
# AttributeError: st.session_state has no attribute "messages". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501 & curl icanhazip.com
# Out:
# 34.125.42.231
# npx: installed 22 in 4.032s
# your url is: https://social-suits-pump.loca.lt

# %%
actuals = []
preds = []
with open('predictions.txt', 'r') as file:
  for line in file:
    print(line)
    try:
      actual = line.strip().split("\t")[0]
      pred   = line.strip().split("\t")[1]
      actuals.append(actual)
      preds.append(pred)
    except Exception as e:
      continue
# Out:
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	False.
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	TRUE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# 	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# FALSE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	TRUE
#
# TRUE	FALSE
#
# TRUE	FALSE

# %%
print(len(actuals), len(preds))
# Out:
# 1011 1011

# %%
print(preds)
# Out:
# ['TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'False.', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'TRUE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', ' ...

# %%
print(np.unique(preds))
# Out:
# ['FALSE' 'TRUE']

# %%
actuals = np.array(actuals)
preds = np.array(preds)
preds = np.where(preds == "False.", "FALSE", preds)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, recall_score
cm = confusion_matrix(np.array(actuals), np.array(preds))
print(cm)

TN, FP, FN, TP = cm.ravel()

precision = precision_score(np.array(actuals), np.array(preds), pos_label="TRUE")
accuracy = accuracy_score(np.array(actuals), np.array(preds))
recall = recall_score(np.array(actuals), np.array(preds), pos_label="TRUE")

print(f"Precision: {precision}")
print(f"Accuracy: {accuracy}")
print(f"Recall: {recall}")
# Out:
# [[549  15]
#  [160 287]]
# Precision: 0.9503311258278145
# Accuracy: 0.8269040553907022
# Recall: 0.6420581655480985

# %%
print(len(actuals), len(preds))
# Out:
# 1011 1011

# %%
relact = actuals[0:339]
irrelact = actuals[340:679]
outact = actuals[680:1011]

relpred = preds[0:339]
irrelpred = preds[340:679]
outpred = preds[680:1011]

# %%
relcm = confusion_matrix(relact, relpred)
irrelcm = confusion_matrix(irrelact, irrelpred)
outcm = confusion_matrix(outact, outpred)

print(relcm)
print(irrelcm)
print(outcm)


relTN, relFP, relFN, relTP = relcm.ravel()
relTN, relFP, relFN, relTP = irrelcm.ravel()
relTN, relFP, relFN, relTP = outcm.ravel()

print("relevant")
precision = precision_score(relact, relpred, pos_label="TRUE")
accuracy = accuracy_score(relact, relpred)
recall = recall_score(relact, relpred, pos_label="TRUE")

print(f"Precision: {precision*100}")
print(f"Accuracy: {accuracy*100}")
print(f"Recall: {recall*100}")

print("irrelevant")

precision = precision_score(irrelact, irrelpred, pos_label="TRUE")
accuracy = accuracy_score(irrelact, irrelpred)
recall = recall_score(irrelact, irrelpred, pos_label="TRUE")

print(f"Precision: {precision*100}")
print(f"Accuracy: {accuracy*100}")
print(f"Recall: {recall*100}")

print("outof")

precision = precision_score(outact, outpred, pos_label="TRUE")
accuracy = accuracy_score(outact, outpred)
recall = recall_score(outact, outpred, pos_label="TRUE")

print(f"Precision: {precision*100}")
print(f"Accuracy: {accuracy*100}")
print(f"Recall: {recall*100}")
# Out:
# [[106  10]
#  [ 19 204]]
# [[338   1]
#  [  0   0]]
# [[104   4]
#  [141  82]]
# relevant
# Precision: 95.32710280373831
# Accuracy: 91.44542772861357
# Recall: 91.4798206278027
# irrelevant
# Precision: 0.0
# Accuracy: 99.70501474926253
# Recall: 0.0
# outof
# Precision: 95.34883720930233
# Accuracy: 56.19335347432024
# Recall: 36.771300448430495
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
